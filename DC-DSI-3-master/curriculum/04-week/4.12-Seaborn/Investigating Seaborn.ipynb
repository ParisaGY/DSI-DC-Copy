# %% [markdown]
# # So Seaborn?
#
#
# While matplot lib is the GrandDaddy of Plotting libraries and has many powerful and intersting visualizations, getting these more advanced visualizations can be a bit time consuming.  Wouldn't it be great if we could build intricate and stacked visualizations quickly for exploratory analysis and presenting findings?
#
# ##### Enter Seaborn
#
# Seaborn is a Python visualization library based on matplotlib. It provides a high-level interface for drawing attractive, statistical graphics.
# Seaborn is a great tool that gives us the ability to visually analyze data in quick and intersting ways.
#
#
# Lets take a look at how we can look at the most basic of datasets in some different ways an see what insights we can draw!

# %%
# importing some libraries and packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# honestly these are always my default imports

# %% [markdown]
# ### What to Import
# While matplotlib uses lists and arrays, certain Seaborn plots work with Pandas DataFrames.
#
# Matplotlib inline is also a requirement if you want to see your visualizations.  Feeling them is free.
#
# matplotlib.pyplot not necessary as seaborn works off this library, so when you import Seaborn you also get its dependent library (matplotlib).  I imported for the sole ability to use 'plt.show()'

# %% [markdown]
# ### Seaborn has Data too?
# ##### Yes!!!
# Similar to Sklearn, Seaborn has a dataframes stored within their library.  All ready to go for analyzing and visualizing!
#
# iris, tips, anscombe and many more here!
# https://github.com/mwaskom/seaborn-data

# %%
iris = sns.load_dataset("iris")
iris.head()
# Look at the pretty DataFrame format!
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ### Pairplot
# Great way to observe correlations right away.
#
# Not great for datasets with many features.

# %%
df = sns.load_dataset("iris")
sns.pairplot(df)
plt.show()
sns.pairplot(df, hue="species")

# %%
sns.pairplot(iris, kind = 'reg')

# %% [markdown]
# ### Treeplots / Swarmplots
# A Less Uncomfortable Violin plot that allows us to observe individual points as well.

# %%
sns.set(style="whitegrid", palette="muted")

# Load the example iris dataset
iris = sns.load_dataset("iris")

# "Melt" the dataset to "long-form" or "tidy" representation
iris = pd.melt(iris, "species", var_name="measurement")

# Draw a categorical scatterplot to show each observation
sns.swarmplot(x="measurement", y="value", hue="species", data=iris)

# %% [markdown]
# ### Jointplot
# Distribution Density and Centroid of two features using a topigraphical map.

# %%
iris = sns.load_dataset("iris") # Last viz warped the data

# Show the joint distribution using kernel density estimation
g = sns.jointplot(iris.petal_length, iris.petal_width, kind="kde", size=7, space=0, ylim = (0,4), xlim = (0,8))

# %%
sns.set(style="ticks")

sns.jointplot(iris.sepal_length, iris.sepal_width, kind="hex", color="dodgerblue")

# %% [markdown]
# ### Anscombe Quartet
# Constructed Straight from the Seaborn citation

# %%
sns.set(style="ticks")

# Load the example dataset for Anscombe's quartet
df = sns.load_dataset("anscombe")

# Show the results of a linear regression within each dataset
sns.lmplot(x="x", y="y", col="dataset", hue="dataset", data=df,
           col_wrap=2, ci=None, palette="muted", size=4,
           scatter_kws={"s": 50, "alpha": 1})

# %% [markdown]
# ## Check it Out!
#
# Use the seaborn Gallary as inspiration and the Data stored in the Seaborn Library to create a visualization you find useful and/or interesting.
#
# Seaborn Gallary - http://seaborn.pydata.org/examples/index.html
#
# Seabron Lib Data - https://github.com/mwaskom/seaborn-data

# %%
# How to load a DataSet with seaborn.
iris = sns.load_dataset('iris')

# %% [markdown]
# ### Easy Seaborn Visualization
# Forget the Fit Regression which is default.
# Robust from Statsmodel will reduce outliers.

# %%
sns.lmplot(x = 'petal_length', y = 'sepal_length', data = iris, hue = 'species', fit_reg = False, robust = True)

# %% [markdown]
# ### Better Pairplot with Scatter and Jointplot

# %%
iris = sns.load_dataset('iris')
g = sns.PairGrid(df, diag_sharey=False)
g.map_lower(sns.kdeplot, cmap="Blues_d")
g.map_upper(plt.scatter)
g.map_diag(sns.kdeplot, lw=3, )
# Out:
# //anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:531: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# ### Just Stacking some Jointplots.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid")
iris = sns.load_dataset("iris")

# Subset the iris dataset by species
setosa = iris.query("species == 'setosa'")
virginica = iris.query("species == 'virginica'")
versicolor = iris.query("species == 'versicolor'")

# Set up the figure
f, ax = plt.subplots(figsize=(8, 8))
ax.set_aspect("equal")

# Draw the two density plots
ax = sns.kdeplot(setosa.sepal_width, setosa.sepal_length,
                 cmap="Reds", shade=True, shade_lowest=False)

ax = sns.kdeplot(versicolor.sepal_width, versicolor.sepal_length,
                 cmap="Greens", shade=True, shade_lowest=False)

ax = sns.kdeplot(virginica.sepal_width, virginica.sepal_length,
                 cmap="Blues", shade=True, shade_lowest=False)

# Add labels to the plot
red = sns.color_palette("Reds")[-2]
blue = sns.color_palette("Blues")[-2]
ax.text(2.5, 8.2, "virginica", size=16, color=blue)
ax.text(3.8, 4.5, "setosa", size=16, color=red)

# %%
# Out:
# u'/Users/General_Assembly/Desktop'
