# %% [markdown]
# ## Automated Data Collection Lab
#
# For this lab, you are asked to produce a list of all of Lincoln's quotes available on this page: http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1 Use the requests and BeautifulSoup libraries in Python.
#
# For a bonus, collect all the quotes from each page available on Successories.

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1"
html = requests.get(url)

# %%
from bs4 import BeautifulSoup
b = BeautifulSoup(html.text)

# print out the object
print (b)
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <title>Abraham Lincoln Quotes |  Successories | Quote Database | Motivational Posters</title><meta content="The largest collection of Abraham Lincoln quotes. Successories iQuote Quote database has gathered 440 of Abraham Lincoln quotes. Search Abraham Lincoln quotes. Put quotes on Motivational Posters and Awards Recognition." name="description"/><meta content="en-us" http-equiv="Content-Language"/>
# <meta content="Employee Gifts, Awards Recognition, Motivational Posters" name="classification"/><meta content="index,follow" name="robots"/>
# <meta content="uJjzLV_M66fPgenvGXEETRewzeCLlM8tyfIn7UYw9zQ" name="google-site-verification"/><meta content="B015DAC7E38DC29941EBB997DC79B420" name="msvalidate.01"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="width=device-width; initial-scale=1.0; maximum-scale=1.0; user-scalable=0;" name="viewport"/>
# <base href="http://www.successories.com/"/>
# <link href="http://www.successories.com/css/combined.php?1481728802" rel="stylesheet" type="text/css"/><!--[if IE 8]><link href="http://www.successories.com/css/ie8.css?1477683325" rel="stylesheet" type="text/css" /><![endif]--><link href="http://www.successories.com/images/favicon.ico?1477683325" rel="shortcut icon"/>
# <link href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1" rel="canonical"/><script src="http://www.successories.com/framework/js/combined.php?1481640934" type="text/javascript"></script>
# </head>
# <body style="margin:0; padding:0; color:#333;	background-color:#FCFCFC;">
# <script type="text/javascript">(function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,'script','//www.google-analytics.com/analytics.js','ga');ga('create','UA-1071924-1','successories.com');ga('require','displayfeatures');ga('send','pageview');</script>
# <div class="wrapper" style="min-height: 100%; height: auto; height: 100%;">
# <script type="text/javascript">var main_menu=new MainMenu("header_submenus");main_menu.addMenuItem(new MainMenuItem("menu_motivational_posters","submenu_motivational_posters","motivational_posters",250));main_menu.addMenuItem(new MainMenuItem("menu_awards_recognition","submenu_awards_recognition","awards_recognition",250));main_menu.addMenuItem(new MainMenuItem("menu_gifts","submenu_gifts","gifts",250));main_menu.addMenuItem(new MainMenuItem("menu_meetings","submenu_meetings","meetings",250));main_menu.addMenuItem(new MainMenuItem("menu_cards","submenu_cards","cards",250));main_menu.addMenuItem(new MainMenuItem("menu_books","submenu_books","books",250));main_menu.addMenuItem(new MainMenuItem("menu_create","submenu_create","create",250));main_menu.addMenuItem(new MainMenuItem("menu_themes","submenu_themes","themes",250));</script>
# <div id="offer_sw"><div class="offer_sw" id="header-source-banner" style="display: none"></div> <div class="offer_sw" id="header-sitewide-banner"></div> </div>
# <div class="header-snow"></div>
# <div id="header" style="margin: 0; padding: 0 0 1px; position: relative;">
# <div id="header-container-outter">
# <div id="header-container" style="position: relative; width: 980px; margin: 0 auto; 	height:80px;">
# <div id="logo" style="left: 15px; position: absolute; top: 0;"><a href="http://www.successories.com/"><img alt="Successories Employee Motivational Gifts and Awards" class="headercart" src="images/gfx-header/Successories-Employee-Motivational-Gifts-and-Awards.png"/></a></div>
# <a class="header-icon" href="http://www.successories.com/cart" id="header_cart_snapshot"><img src="images/gfx-header/cart2.png"/><span class="carttotal" id="header-cart-snapshot">0 items</span></a>
# <a class="header-icon" href="https://www.successories.com/account/favorite-products" id="header_favorites_snapshot"><img class="header-favorite" src="images/gfx-header/favorite.png"/><span>Account</span></a>
# <div class="header-icon mobile-sm-hide" id="header_phone_number" style="display:none"><strong>1-800-535-2773</strong><br/><span>Call Us 8am-10pm ET</span></div>
# <a class="mobile-sm-show header-icon" href="tel:18005352773" id="header-global-call-mobile"><img onclick="" src="images/gfx-header/call-mobile.jpg"/></a>
# <a class="header-icon" id="header_menu_mobile-show" onclick="Activa.DOM.addClass('header-global-nav', 'show'); Activa.DOM.showID('header_menu_mobile-hide'); Activa.DOM.hideID('header_menu_mobile-show'); Activa.DOM.hideID('header-global-search-mobile');"><img class="header-menu" src="images/gfx-header/menu-mobile.jpg"/></a>
# <a class="header-icon" id="header_menu_mobile-hide" onclick="Activa.DOM.removeClass('header-global-nav', 'show'); Activa.DOM.showID('header_menu_mobile-show'); Activa.DOM.hideID('header_menu_mobile-hide'); Activa.DOM.hideID('header-global-search-mobile');" style="display:none"><img class="header-menu" src="images/gfx-header/menu-mobile.jpg"/></a>
# <a class="header-icon" id="header_search_mobile-show" onclick="Activa.DOM.showID('header-global-search-mobile'); Activa.DOM.showID('header_search_mobile-hide'); Activa.DOM.hideID('header_search_mobile-show'); Activa.DOM.removeClass('header-global-nav', 'show');"><img class="header-search" src="images/gfx-header/search-mobile.jpg"/></a>
# <a class="header-icon" id="header_search_mobile-hide" onclick="Activa.DOM.hideID('header-global-search-mobile'); Activa.DOM.showID('header_search_mobile-show'); Activa.DOM.hideID('header_search_mobile-hide'); Activa.DOM.removeClass('header-global-nav', 'show');" style="display:none"><img src="images/gfx-header/search-mobile.jpg"/></a>
# <div class="clear"></div>
# </div>
# <div class="clear"></div>
# </div>
# <div class="clear"></div>
# </div>
# <div class="clear"></div>
# <div class="header-nav">
# <div class="" id="header-global-nav">
# <div class="header-global-nav-container">
# <ul class="nav main clear">
# <a href="http://www.successories.com/Office-Art-Posters/1" id="menu_motivational_posters">Motivational <br/>Posters &amp; Art</a>
# <a href="http://www.successories.com/Employee-Awards-Recognition/1" id="menu_awards_recognition">Awards &amp; <br/>Recognition</a>
# <a href="http://www.successories.com/Unique-Corporate-Gifts/1" id="menu_gifts">Gifts &amp; <br/>Rewards</a>
# <a href="http://www.successories.com/Fun-Motivation-Gifts/1" id="menu_gifts">Fun <br/>Motivation</a>
# <a href="http://www.successories.com/Motivational-Gifts/1" id="menu_meetings">Meeting &amp; Event <br/>Giveaways</a>
# <a class="oneline" href="http://www.successories.com/Business-Greeting-Cards/1" id="menu_cards">Cards</a>
# <a class="oneline" href="http://www.successories.com/Inspirational-Books/1" id="menu_books">Books</a>
# <a href="http://www.successories.com/categories/Shop-By-Theme/5041/1" id="menu_themes">Shop by <br/>Themes</a>
# <a href="http://www.successories.com/categories/Create-Your-Own/302/1" id="menu_create">Custom <br/>Photo Gifts</a>
# <a class="oneline" href="http://www.successories.com/categories/New-Products/3499/1">NEW</a>
# <a class="short red" href="http://www.successories.com/Employee-Holiday-Gifts/1?source=SW6DC3O">Holiday <br/>Delivery</a>
# <a class="web-hide menu-close" onclick="Activa.DOM.removeClass('header-global-nav', 'show'); Activa.DOM.showID('header_menu_mobile-show'); Activa.DOM.hideID('header_menu_mobile-hide');">[x] Close Menu</a>
# </ul>
# <div class="clear"></div>
# </div>
# </div>
# <div id="header_submenus" style="display: none; overflow: hidden; height: 300px;">
# <div id="submenu_motivational_posters" style="display: none;"><div class="SubMenuBody"><img class="loading-submenu" src="images/gfx-submenu/loading.gif"/></div></div>
# <div id="submenu_awards_recognition" style="display: none;"><div class="SubMenuBody"><img alt="loading" class="loading-submenu" src="images/gfx-submenu/loading.gif"/></div></div>
# <div id="submenu_gifts" style="display: none;"><div class="SubMenuBody"><img alt="loading" class="loading-submenu" src="images/gfx-submenu/loading.gif"/></div></div>
# <div id="submenu_meetings" style="display: none;"><div class="SubMenuBody"><img alt="loading" class="loading-submenu" src="images/gfx-submenu/loading.gif"/></div></div>
# <div id="submenu_cards" style="display: none;"><div class="SubMenuBody"><img alt="loading" class="loading-submenu" src="images/gfx-submenu/loading.gif"/></div></div>
# <div id="submenu_books" style="display: none;"><div class="SubMenuBody"><img alt="loading" class="loading-submenu" src="images/gfx-submenu/loading.gif"/></div></div>
# <div id="submenu_create" style="display: none;"><div class="SubMenuBody"><img alt="loading" class="loading-submenu" src="images/gfx-submenu/loading.gif"/></div></div>
# <div id="submenu_themes" style="display: none;"><div class="SubMenuBody"><img alt="loading" class="loading-submenu" src="images/gfx-submenu/loading.gif"/></div></div>
# <div id="submenu_events" style="display: none;"><div class="SubMenuBody"><img alt="loading" class="loading-submenu" src="images/gfx-submenu/loading.gif"/></div></div>
# </div>
# </div>
# <div id="header-global-search-mobile" style="display:none;"><form action="http://www.successories.com/search/results" class="search" method="post" onsubmit="if ( this.elements['search'].value == 'enter your search' ) { alert('Please enter your search'); return false; } else { return true; } "><div class="searchInputs"><input autocomplete="off" class="search_box" id="header_search" name="search" onblur="leaveField(this, 'What are you looking for?');" onfocus="enterField(this, 'What are you looking for?');" type="text" value="What are you looking for?"/><input class="btn_global_search" src="images/gfx-header/search.jpg" type="image" value="Search"/></div></form></div>
# <a class="mobile-sm-show call-btn" href="tel:18005352773"><img src="images/gfx-header/call.png"/></a>
# <div class="clear" id="container">
# <div class="clear" id="category">
# <div class="clear" id="quotedb">
# <ul class="quotedb_tabs clear">
# <li><a href="http://www.successories.com/iquote/keywords">Keywords</a></li>
# <li><a href="http://www.successories.com/iquote/categories">Categories</a></li>
# <li class="current"><a href="http://www.successories.com/iquote/authors">Authors</a></li>
# <li class="mobile-hide"><a href="http://www.successories.com/iquote/my">My Quotes</a></li>
# <li class="mobile-hide"><a href="http://www.successories.com/iquote/quoteology">Quoteology</a></li>
# <li class="mobile-hide"><a href="http://www.successories.com/iquote/today">Today's iQuote</a></li>
# </ul> </div>
# <div class="quotedb_quotelist">
# <h1><a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1" style="float:left; margin-right:10px;">Abraham Lincoln Quotes</a></h1>
# <iframe allowtransparency="true" frameborder="0" scrolling="no" src="http://www.facebook.com/plugins/like.php?href=http%3A%2F%2Fwww.successories.com%2Fiquote%2Fauthor%2F291%2Fabraham-lincoln-quotes%2F1&amp;send=false&amp;layout=button_count&amp;width=100&amp;show_faces=false&amp;action=like&amp;colorscheme=light&amp;font&amp;height=21" style="border:none; overflow:hidden; width:100px; height:21px; float:left;"></iframe>
# <br clear="all"/>
# <h3><ul class="pager">
# <li class="on"><a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">1</a></li>
# <li><a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/2">2</a></li>
# <li><a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/3">3</a></li>
# <li><a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/4">4</a></li>
# <li><a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/5">5</a></li>
# <li class="ellipsis"><span>...</span></li>
# <li><a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/44">44</a></li>
# <li><a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/2"><img alt="Next" height="8" src="images/gfx-listview/pager-next.gif" width="8"/></a></li>
# </ul>
#   440 quotes:</h3>
# <div class="quotebox">
# <div class="quote"><a onclick="location = 'http://www.successories.com/iquote/quote/989347/i-am-for-those-means-which-will-give-the-greatest-good-to-the-greatest-number'; return false;">"I am for those means which will give the greatest good to the greatest number."</a></div>
# <div class="aboutquote">
# <span class="author">Author: <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">Lincoln Quotes</a></span>
#         	Category:
#     		    		<i>None</i>
# </div>
# <div class="quote_actions">
# <div class="wingdings" id="quote_controls_989347"></div>
# <script type="text/javascript">new Quote(989347,"",false);</script>
# </div>
# </div>
# <!-- Go to www.addthis.com/dashboard to customize your tools -->
# <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript"></script> <div class="quotebox">
# <div class="quote"><a onclick="location = 'http://www.successories.com/iquote/quote/111287/having-thus-chosen-our-course-without-guile-and-with-pure-purpose-let-us-renew-our-trust-in-god-a'; return false;">"Having thus chosen our course, without guile and with pure purpose, let us renew our trust in God, and go forward without fear and with manly hearts."</a></div>
# <div class="aboutquote">
# <span class="author">Author: <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">Lincoln Quotes</a></span>
#         	Category:
#     		    		    		    		    		    		<a href="http://www.successories.com/iquote/category/392/brave-quotes/1">Brave Quotes</a>
#     		    		    		    		    		    		    		Respectability Quotes
#     		    		    		    </div>
# <div class="quote_actions">
# <div class="wingdings" id="quote_controls_111287"></div>
# <script type="text/javascript">new Quote(111287,"",false);</script>
# </div>
# </div>
# <!-- Go to www.addthis.com/dashboard to customize your tools -->
# <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript"></script> <div class="quotebox">
# <div class="quote"><a onclick="location = 'http://www.successories.com/iquote/quote/73400/you-have-to-do-your-own-growing-no-matter-how-tall-your-grandfather-was'; return false;">"You have to do your own growing no matter how tall your grandfather was."</a></div>
# <div class="aboutquote">
# <span class="author">Author: <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">Lincoln Quotes</a></span>
#         	Category:
#     		    		    		    		    		    		<a href="http://www.successories.com/iquote/category/160/american-president-quotes/1">American President Quotes</a>
# <a href="http://www.successories.com/iquote/category/738/courage-quotes/1">Courage Quotes</a>
# </div>
# <div class="quote_actions">
# <div class="wingdings" id="quote_controls_73400"></div>
# <script type="text/javascript">new Quote(73400,"",false);</script>
# </div>
# </div>
# <!-- Go to www.addthis.com/dashboard to customize your tools -->
# <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript"></script> <div class="quotebox">
# <div class="quote"><a onclick="location = 'http://www.successories.com/iquote/quote/73363/i-have-been-driven-many-times-to-my-knees-by-the-overwhelming-conviction-that-i-had-nowhere-to-go-m'; return false;">"I have been driven many times to my knees by the overwhelming conviction that I had nowhere to go. My own wisdom, and that of all about me, seemed insufficient for the day."</a></div>
# <div class="aboutquote">
# <span class="author">Author: <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">Lincoln Quotes</a></span>
#         	Category:
#     		    		    		    		    		    		<a href="http://www.successories.com/iquote/category/160/american-president-quotes/1">American President Quotes</a>
# <a href="http://www.successories.com/iquote/category/719/conviction-quotes/1">Conviction Quotes</a>
# </div>
# <div class="quote_actions">
# <div class="wingdings" id="quote_controls_73363"></div>
# <script type="text/javascript">new Quote(73363,"",false);</script>
# </div>
# </div>
# <!-- Go to www.addthis.com/dashboard to customize your tools -->
# <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript"></script> <div class="quotebox">
# <div class="quote"><a onclick="location = 'http://www.successories.com/iquote/quote/22247/i-see-a-very-dark-cloud-on-americas-horizon-and-that-cloud-is-coming-from-rome'; return false;">"I see a very dark cloud on America's horizon, and that cloud is coming from Rome"</a></div>
# <div class="aboutquote">
# <span class="author">Author: <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">Lincoln Quotes</a></span>
#         	Category:
#     		    		    		    		    		    		<a href="http://www.successories.com/iquote/category/116/america-quotes/1">America Quotes</a>
# </div>
# <div class="quote_actions">
# <div class="wingdings" id="quote_controls_22247"></div>
# <script type="text/javascript">new Quote(22247,"",false);</script>
# </div>
# </div>
# <!-- Go to www.addthis.com/dashboard to customize your tools -->
# <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript"></script> <div class="quotebox">
# <div class="quote"><a onclick="location = 'http://www.successories.com/iquote/quote/10363/things-may-come-to-those-who-wait-but-only-the-things-left-by-those-who-hustle'; return false;">"Things may come to those who wait...but only the things left by those who hustle."</a></div>
# <div class="aboutquote">
# <span class="author">Author: <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">Lincoln Quotes</a></span>
#         	Category:
#     		    		    		    		    		    		<a href="http://www.successories.com/iquote/category/87/achievement-quotes/1">Achievement Quotes</a>
# </div>
# <div class="quote_actions">
# <div class="wingdings" id="quote_controls_10363"></div>
# <script type="text/javascript">new Quote(10363,"",false);</script>
# </div>
# </div>
# <!-- Go to www.addthis.com/dashboard to customize your tools -->
# <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript"></script> <div class="quotebox">
# <div class="quote"><a onclick="location = 'http://www.successories.com/iquote/quote/989371/lonely-men-seek-companionship-lonely-women-sit-at-home-and-wait-they-never-meet'; return false;">"Lonely men seek companionship. Lonely women sit at home and wait. They never meet."</a></div>
# <div class="aboutquote">
# <span class="author">Author: <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">Lincoln Quotes</a></span>
#         	Category:
#     		    		<i>None</i>
# </div>
# <div class="quote_actions">
# <div class="wingdings" id="quote_controls_989371"></div>
# <script type="text/javascript">new Quote(989371,"",false);</script>
# </div>
# </div>
# <!-- Go to www.addthis.com/dashboard to customize your tools -->
# <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript"></script> <div class="quotebox">
# <div class="quote"><a onclick="location = 'http://www.successories.com/iquote/quote/989370/and-in-the-end-its-not-the-years-in-your-life-that-count-its-the-life-in-your-years'; return false;">"And in the end it's not the years in your life that count. It's the life in your years."</a></div>
# <div class="aboutquote">
# <span class="author">Author: <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">Lincoln Quotes</a></span>
#         	Category:
#     		    		<i>None</i>
# </div>
# <div class="quote_actions">
# <div class="wingdings" id="quote_controls_989370"></div>
# <script type="text/javascript">new Quote(989370,"",false);</script>
# </div>
# </div>
# <!-- Go to www.addthis.com/dashboard to customize your tools -->
# <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript"></script> <div class="quotebox">
# <div class="quote"><a onclick="location = 'http://www.successories.com/iquote/quote/989369/it-is-difficult-to-make-a-man-miserable-while-he-feels-he-is-worthy-of-himself-and-claims-kindred-to'; return false;">"It is difficult to make a man miserable while he feels he is worthy of himself and claims kindred to the great God who made him."</a></div>
# <div class="aboutquote">
# <span class="author">Author: <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">Lincoln Quotes</a></span>
#         	Category:
#     		    		<i>None</i>
# </div>
# <div class="quote_actions">
# <div class="wingdings" id="quote_controls_989369"></div>
# <script type="text/javascript">new Quote(989369,"",false);</script>
# </div>
# </div>
# <!-- Go to www.addthis.com/dashboard to customize your tools -->
# <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript"></script> <div class="quotebox">
# <div class="quote"><a onclick="location = 'http://www.successories.com/iquote/quote/989368/every-man-is-said-to-have-his-peculiar-ambition'; return false;">"Every man is said to have his peculiar ambition."</a></div>
# <div class="aboutquote">
# <span class="author">Author: <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">Lincoln Quotes</a></span>
#         	Category:
#     		    		<i>None</i>
# </div>
# <div class="quote_actions">
# <div class="wingdings" id="quote_controls_989368"></div>
# <script type="text/javascript">new Quote(989368,"",false);</script>
# </div>
# </div>
# <!-- Go to www.addthis.com/dashboard to customize your tools -->
# <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript"></script>
# <ul class="pager">
# <li class="on"><a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">1</a></li>
# <li><a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/2">2</a></li>
# <li><a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/3">3</a></li>
# <li><a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/4">4</a></li>
# <li><a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/5">5</a></li>
# <li class="ellipsis"><span>...</span></li>
# <li><a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/44">44</a></li>
# <li><a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/2"><img alt="Next" height="8" src="images/gfx-listview/pager-next.gif" width="8"/></a></li>
# </ul>
# <br clear="all"/>
# </div>
# </div>
# <div id="quotedb-left-sidebar">
# <a href="http://www.successories.com/iquote/authors/most"><img alt="inspirational quote database" src="images/gfx-quotedb/quote-database2.gif" title="iQuote: Inspirational Quote Database"/></a>
# <br/><br/>
# <p>Successories, the leaders of inspiration and motivation, has unlocked iQuote: The Inspirational Quote Database, a curated collection of the most inspirational quotes. Raise your iQ and become a Quoteologist today!</p>
# <br/>
# <form action="http://www.successories.com/iquote/today/submit" method="post">
# <div class="quote_signup2">
#         iQuote in your inbox! <b>Sign Up!</b><br/>
# <input class="typed" id="quote_email" name="email" type="text" value="enter your email address"/>
# <script type="text/javascript">setupFocusBlur("quote_email","enter your email address");</script>
# <input class="quote_signup-button" type="submit" value=""/>
# </div>
# </form>
# </div>
# <!-- END Content -->
# </div>
# <div class="push"></div>
# </div><!-- END Wrapper -->
# <!-- START Footer -->
# <div id="Clients"><div class="ClientListTitle">Successories has been providing motivation to organizations like yours since 1985</div><div class="ClientList"></div></div>
# <div id="Footer-Signup">
# <div id="container-secondary">
# <div class="footer_email">
# <div class="footer-title">Sign up and Receive 10% Off:</div>
# <form action="https://www.successories.com/newsletter-signup" method="post">
# <input class="signup_box" name="newsletter_email" onblur="leaveField(this, 'enter your email address');" onfocus="enterField(this, 'enter your email address');" style="color:#999999;" type="email" value="enter your email address"/><input class="btn_green btn_small" type="submit" value="Sign Up"/>
# </form>
# </div>
# <div class="footer_social mobile-hide">
# <div class="addthis_horizontal_follow_toolbox"></div>
# <div class="footer-title">Stay Connected:</div>
# </div>
# <div class="clear"></div>
# </div>
# </div>
# <div class="footer" id="footer">
# <div class="footer-winter"></div>
# <div class="footer-content">
# <div class="footer-onefourth firstfourth">
# <div class="footerTitle">Get Your FREE Successories Catalog</div>
# <a href="http://www.successories.com/catalog-request"> <img alt="Catalog" height="100px" src="images/gfx-home_page/2016-03-11/Catalog.png" width="111px"/></a>
# <br clear="all"/><a href="http://www.successories.com/catalog-request">Request a Catalog →</a><br clear="all"/>
# </div>
# <div class="footer-onefourth secondfourth mobile-hide" onclick="window.open('http://www.successories.com/blog/?p=3264'); return false;">
# <img border="0" height="59" src="images/gfx-footer/UPS-white.png" width="50"/><div>We Proudly Ship<br/>Using UPS<br/>carbon neutral</div>
# </div>
# <div class="footer-onefourth thirdfourth">
# <div class="cc-badges" onclick="window.open('https://sealinfo.thawte.com/thawtesplash?form_file=fdf/thawtesplash.fdf&amp;dn=WWW.SUCCESSORIES.COM&amp;lang=en'); return false;">Secure Checkout by Thawte. Powered by Paypal.</div>
# <div class="bestplacestowork mobile-hide" onclick="window.open('http://www.successories.com/blog/2015/09/30/successories-named-best-place-to-work/'); return false;">Voted Best Places to Work Year after Year</div>
# </div>
# <div class="footer-onefourth fourthfourth">
# <div class="footerTitle">Customer Service:</div>
# <li><a onclick="location='http://www.successories.com/contact-us'">Contact Us</a></li>
# <li><a onclick="location='http://www.successories.com/guarantee'">100% Satisfaction Guarantee</a></li>
# <li><a onclick="location='http://www.successories.com/art-requirements'">Art &amp; Logo Requirements</a></li>
# <li><a onclick="location='http://www.successories.com/ordering-shipping'">Ordering &amp; Shipping</a></li>
# <li><a onclick="location='http://www.successories.com/international-checkout'">International Ordering</a></li>
# <li><a onclick="location='http://www.successories.com/returns-exchanges'">Returns &amp; Exchanges</a></li>
# <li><a onclick="location='http://www.successories.com/categories/Closeout-and-Sale-Center/283/1'">Outlet Center</a></li> <li><a onclick="location='http://www.successories.com/catalog-request'">Request a Catalog</a></li>
# <br clear="all"/>
# <div class="footerTitle">Resources:</div>
# <li><a href="http://www.successories.com/Resources">Whitepapers &amp; More</a></li>
# <li><a href="http://www.successories.com/blog">Successories Blog</a></li>
# <li><a href="http://www.successories.com/iquote/authors">Quote Database</a></li>
# </div>
# <br clear="all"/>
# <div class="clear"></div>
# <div class="subfooter">
# <div class="copyrightLine clear">
# 				800-535-2773 © Copyright 2016, Successories.com, LLC. All Rights Reserved.
# 				<a onclick="location='http://www.successories.com/privacy'">Privacy</a> | <a onclick="location='http://www.successories.com/terms'">Terms</a> | <a href="http://www.successories.com/sitemap">Site Map</a> <br clear="all"/><br clear="all"/>
# <p><strong>Terms &amp; Conditions:</strong> Must use desired promo code in cart. Minimum merchandise purchase may apply. Can expire or change at anytime. Limited 1 time use per customer. Limited to US &amp; Canadian orders. Shipping offers limited to Contiguous US shipping addresses with ground service to one location. Cannot be combined with any other discounts or promotions such as sale items, quantity discounts, and multiple promo codes. Promotion excludes promotional products. Other exclusions may apply. Promotion does not apply to previous purchases, taxes, or other shipping methods. Subject to adjustment due to returns, cancellations and exchanges. Valid only at www.successories.com </p>
# </div>
# <br clear="all"/>
# </div>
# <!-- START RPC Header Update -->
# <script type="text/javascript">var s192="k4+E2VN30d4fmXK6XAqKrlP257WYOLEar8oT7Ujqey529IlpLEZKs+CXc/VydSQEbIY8raoFcpV3zGFUG2apPinVnq2f4rKCzZCZCVIkKDqeayrBB74JNRXyyoF2e2DdyJELymuSQR8rLkBngUQ/A7V2Twuz1Hp8XrqdaJnDEq0=";function s833(){var s91={v:s192};new Activa.rpc("http://www.successories.com/rpc/tr/p",{input:s91,onComplete:function(){}});s192="";}
# setInterval(s833,60000);Activa.DOM.ready(updateHeaderInfo);Activa.DOM.ready(s833);</script>
# <!-- Google Code for Remarketing Tag -->
# <script type="text/javascript">
# var google_tag_params = {"ecomm_pagetype":"other"};
# </script>
# <script type="text/javascript">
# /* <![CDATA[ */
# var google_conversion_id = 1069719471;
# var google_custom_params = window.google_tag_params;
# var google_remarketing_only = true;
# /* ]]> */
# </script>
# <script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript">
# </script>
# <noscript>
# <div style="display:inline;">
# <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/1069719471/?value=0&amp;guid=ON&amp;script=0" style="border-style:none;" width="1"/>
# </div>
# </noscript>
# <!-- BEGIN: Google Trusted Stores -->
# <script type="text/javascript">
# var gts = gts || [];
# gts.push(["id", "199541"]);
# gts.push(["locale", "en_US"]);
# gts.push(["google_base_subaccount_id", "199541"]);
# gts.push(["google_base_country", "US"]);
# gts.push(["google_base_language", "en"]);
# (function() {
# var scheme = (("https:" == document.location.protocol) ? "https://" : "http://");
# var gts = document.createElement("script");
# gts.type = "text/javascript";
# gts.async = true;
# gts.src = scheme + "www.googlecommerce.com/trustedstores/gtmp_compiled.js";
# var s = document.getElementsByTagName("script")[0];
# s.parentNode.insertBefore(gts, s);
# })();
# </script>
# <!-- END: Google Trusted Stores -->
# <!-- START Bronto -->
# <script type="text/javascript">
#   var _bsw = _bsw || [];
#   _bsw.push(['_bswId', '846aeb2eec3570f51a785acf3f0055cb4eca692c5b6785c2bf2e9aced32f9587']);
#   (function() {
#     var bsw = document.createElement('script'); bsw.type = 'text/javascript'; bsw.async = true;
#     bsw.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'js.bronto.com/s/b.min.js';
#     var t = document.getElementsByTagName('script')[0]; t.parentNode.insertBefore(bsw, t);
#   })();
# </script>
# <!-- END Bronto -->
# <!-- START AddThis -->
# <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript"></script>
# <!-- END AddThis --> </div><!-- END Footer Container -->
# </div><!-- END Footer -->
# </body>
# </html>
#
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    Abraham Lincoln Quotes |  Successories | Quote Database | Motivational Posters
#   </title>
#   <meta content="The largest collection of Abraham Lincoln quotes. Successories iQuote Quote database has gathered 440 of Abraham Lincoln quotes. Search Abraham Lincoln quotes. Put quotes on Motivational Posters and Awards Recognition." name="description"/>
#   <meta content="en-us" http-equiv="Content-Language"/>
#   <meta content="Employee Gifts, Awards Recognition, Motivational Posters" name="classification"/>
#   <meta content="index,follow" name="robots"/>
#   <meta content="uJjzLV_M66fPgenvGXEETRewzeCLlM8tyfIn7UYw9zQ" name="google-site-verification"/>
#   <meta content="B015DAC7E38DC29941EBB997DC79B420" name="msvalidate.01"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width; initial-scale=1.0; maximum-scale=1.0; user-scalable=0;" name="viewport"/>
#   <base href="http://www.successories.com/"/>
#   <link href="http://www.successories.com/css/combined.php?1481728802" rel="stylesheet" type="text/css"/>
#   <!--[if IE 8]><link href="http://www.successories.com/css/ie8.css?1477683325" rel="stylesheet" type="text/css" /><![endif]-->
#   <link href="http://www.successories.com/images/favicon.ico?1477683325" rel="shortcut icon"/>
#   <link href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1" rel="canonical"/>
#   <script src="http://www.successories.com/framework/js/combined.php?1481640934" type="text/javascript">
#   </script>
#  </head>
#  <body style="margin:0; padding:0; color:#333;	background-color:#FCFCFC;">
#   <script type="text/javascript">
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,'script','//www.google-analytics.com/analytics.js','ga');ga('create','UA-1071924-1','successories.com');ga('require','displayfeatures');ga('send','pageview');
#   </script>
#   <div class="wrapper" style="min-height: 100%; height: auto; height: 100%;">
#    <script type="text/javascript">
#     var main_menu=new MainMenu("header_submenus");main_menu.addMenuItem(new MainMenuItem("menu_motivational_posters","submenu_motivational_posters","motivational_posters",250));main_menu.addMenuItem(new MainMenuItem("menu_awards_recognition","submenu_awards_recognition","awards_recognition",250));main_menu.addMenuItem(new MainMenuItem("menu_gifts","submenu_gifts","gifts",250));main_menu.addMenuItem(new MainMenuItem("menu_meetings","submenu_meetings","meetings",250));main_menu.addMenuItem(new MainMenuItem("menu_cards","submenu_cards","cards",250));main_menu.addMenuItem(new MainMenuItem("menu_books","submenu_books","books",250));main_menu.addMenuItem(new MainMenuItem("menu_create","submenu_create","create",250));main_menu.addMenuItem(new MainMenuItem("menu_themes","submenu_themes","themes",250));
#    </script>
#    <div id="offer_sw">
#     <div class="offer_sw" id="header-source-banner" style="display: none">
#     </div>
#     <div class="offer_sw" id="header-sitewide-banner">
#     </div>
#    </div>
#    <div class="header-snow">
#    </div>
#    <div id="header" style="margin: 0; padding: 0 0 1px; position: relative;">
#     <div id="header-container-outter">
#      <div id="header-container" style="position: relative; width: 980px; margin: 0 auto; 	height:80px;">
#       <div id="logo" style="left: 15px; position: absolute; top: 0;">
#        <a href="http://www.successories.com/">
#         <img alt="Successories Employee Motivational Gifts and Awards" class="headercart" src="images/gfx-header/Successories-Employee-Motivational-Gifts-and-Awards.png"/>
#        </a>
#       </div>
#       <a class="header-icon" href="http://www.successories.com/cart" id="header_cart_snapshot">
#        <img src="images/gfx-header/cart2.png"/>
#        <span class="carttotal" id="header-cart-snapshot">
#         0 items
#        </span>
#       </a>
#       <a class="header-icon" href="https://www.successories.com/account/favorite-products" id="header_favorites_snapshot">
#        <img class="header-favorite" src="images/gfx-header/favorite.png"/>
#        <span>
#         Account
#        </span>
#       </a>
#       <div class="header-icon mobile-sm-hide" id="header_phone_number" style="display:none">
#        <strong>
#         1-800-535-2773
#        </strong>
#        <br/>
#        <span>
#         Call Us 8am-10pm ET
#        </span>
#       </div>
#       <a class="mobile-sm-show header-icon" href="tel:18005352773" id="header-global-call-mobile">
#        <img onclick="" src="images/gfx-header/call-mobile.jpg"/>
#       </a>
#       <a class="header-icon" id="header_menu_mobile-show" onclick="Activa.DOM.addClass('header-global-nav', 'show'); Activa.DOM.showID('header_menu_mobile-hide'); Activa.DOM.hideID('header_menu_mobile-show'); Activa.DOM.hideID('header-global-search-mobile');">
#        <img class="header-menu" src="images/gfx-header/menu-mobile.jpg"/>
#       </a>
#       <a class="header-icon" id="header_menu_mobile-hide" onclick="Activa.DOM.removeClass('header-global-nav', 'show'); Activa.DOM.showID('header_menu_mobile-show'); Activa.DOM.hideID('header_menu_mobile-hide'); Activa.DOM.hideID('header-global-search-mobile');" style="display:none">
#        <img class="header-menu" src="images/gfx-header/menu-mobile.jpg"/>
#       </a>
#       <a class="header-icon" id="header_search_mobile-show" onclick="Activa.DOM.showID('header-global-search-mobile'); Activa.DOM.showID('header_search_mobile-hide'); Activa.DOM.hideID('header_search_mobile-show'); Activa.DOM.removeClass('header-global-nav', 'show');">
#        <img class="header-search" src="images/gfx-header/search-mobile.jpg"/>
#       </a>
#       <a class="header-icon" id="header_search_mobile-hide" onclick="Activa.DOM.hideID('header-global-search-mobile'); Activa.DOM.showID('header_search_mobile-show'); Activa.DOM.hideID('header_search_mobile-hide'); Activa.DOM.removeClass('header-global-nav', 'show');" style="display:none">
#        <img src="images/gfx-header/search-mobile.jpg"/>
#       </a>
#       <div class="clear">
#       </div>
#      </div>
#      <div class="clear">
#      </div>
#     </div>
#     <div class="clear">
#     </div>
#    </div>
#    <div class="clear">
#    </div>
#    <div class="header-nav">
#     <div class="" id="header-global-nav">
#      <div class="header-global-nav-container">
#       <ul class="nav main clear">
#        <a href="http://www.successories.com/Office-Art-Posters/1" id="menu_motivational_posters">
#         Motivational
#         <br/>
#         Posters &amp; Art
#        </a>
#        <a href="http://www.successories.com/Employee-Awards-Recognition/1" id="menu_awards_recognition">
#         Awards &amp;
#         <br/>
#         Recognition
#        </a>
#        <a href="http://www.successories.com/Unique-Corporate-Gifts/1" id="menu_gifts">
#         Gifts &amp;
#         <br/>
#         Rewards
#        </a>
#        <a href="http://www.successories.com/Fun-Motivation-Gifts/1" id="menu_gifts">
#         Fun
#         <br/>
#         Motivation
#        </a>
#        <a href="http://www.successories.com/Motivational-Gifts/1" id="menu_meetings">
#         Meeting &amp; Event
#         <br/>
#         Giveaways
#        </a>
#        <a class="oneline" href="http://www.successories.com/Business-Greeting-Cards/1" id="menu_cards">
#         Cards
#        </a>
#        <a class="oneline" href="http://www.successories.com/Inspirational-Books/1" id="menu_books">
#         Books
#        </a>
#        <a href="http://www.successories.com/categories/Shop-By-Theme/5041/1" id="menu_themes">
#         Shop by
#         <br/>
#         Themes
#        </a>
#        <a href="http://www.successories.com/categories/Create-Your-Own/302/1" id="menu_create">
#         Custom
#         <br/>
#         Photo Gifts
#        </a>
#        <a class="oneline" href="http://www.successories.com/categories/New-Products/3499/1">
#         NEW
#        </a>
#        <a class="short red" href="http://www.successories.com/Employee-Holiday-Gifts/1?source=SW6DC3O">
#         Holiday
#         <br/>
#         Delivery
#        </a>
#        <a class="web-hide menu-close" onclick="Activa.DOM.removeClass('header-global-nav', 'show'); Activa.DOM.showID('header_menu_mobile-show'); Activa.DOM.hideID('header_menu_mobile-hide');">
#         [x] Close Menu
#        </a>
#       </ul>
#       <div class="clear">
#       </div>
#      </div>
#     </div>
#     <div id="header_submenus" style="display: none; overflow: hidden; height: 300px;">
#      <div id="submenu_motivational_posters" style="display: none;">
#       <div class="SubMenuBody">
#        <img class="loading-submenu" src="images/gfx-submenu/loading.gif"/>
#       </div>
#      </div>
#      <div id="submenu_awards_recognition" style="display: none;">
#       <div class="SubMenuBody">
#        <img alt="loading" class="loading-submenu" src="images/gfx-submenu/loading.gif"/>
#       </div>
#      </div>
#      <div id="submenu_gifts" style="display: none;">
#       <div class="SubMenuBody">
#        <img alt="loading" class="loading-submenu" src="images/gfx-submenu/loading.gif"/>
#       </div>
#      </div>
#      <div id="submenu_meetings" style="display: none;">
#       <div class="SubMenuBody">
#        <img alt="loading" class="loading-submenu" src="images/gfx-submenu/loading.gif"/>
#       </div>
#      </div>
#      <div id="submenu_cards" style="display: none;">
#       <div class="SubMenuBody">
#        <img alt="loading" class="loading-submenu" src="images/gfx-submenu/loading.gif"/>
#       </div>
#      </div>
#      <div id="submenu_books" style="display: none;">
#       <div class="SubMenuBody">
#        <img alt="loading" class="loading-submenu" src="images/gfx-submenu/loading.gif"/>
#       </div>
#      </div>
#      <div id="submenu_create" style="display: none;">
#       <div class="SubMenuBody">
#        <img alt="loading" class="loading-submenu" src="images/gfx-submenu/loading.gif"/>
#       </div>
#      </div>
#      <div id="submenu_themes" style="display: none;">
#       <div class="SubMenuBody">
#        <img alt="loading" class="loading-submenu" src="images/gfx-submenu/loading.gif"/>
#       </div>
#      </div>
#      <div id="submenu_events" style="display: none;">
#       <div class="SubMenuBody">
#        <img alt="loading" class="loading-submenu" src="images/gfx-submenu/loading.gif"/>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div id="header-global-search-mobile" style="display:none;">
#     <form action="http://www.successories.com/search/results" class="search" method="post" onsubmit="if ( this.elements['search'].value == 'enter your search' ) { alert('Please enter your search'); return false; } else { return true; } ">
#      <div class="searchInputs">
#       <input autocomplete="off" class="search_box" id="header_search" name="search" onblur="leaveField(this, 'What are you looking for?');" onfocus="enterField(this, 'What are you looking for?');" type="text" value="What are you looking for?"/>
#       <input class="btn_global_search" src="images/gfx-header/search.jpg" type="image" value="Search"/>
#      </div>
#     </form>
#    </div>
#    <a class="mobile-sm-show call-btn" href="tel:18005352773">
#     <img src="images/gfx-header/call.png"/>
#    </a>
#    <div class="clear" id="container">
#     <div class="clear" id="category">
#      <div class="clear" id="quotedb">
#       <ul class="quotedb_tabs clear">
#        <li>
#         <a href="http://www.successories.com/iquote/keywords">
#          Keywords
#         </a>
#        </li>
#        <li>
#         <a href="http://www.successories.com/iquote/categories">
#          Categories
#         </a>
#        </li>
#        <li class="current">
#         <a href="http://www.successories.com/iquote/authors">
#          Authors
#         </a>
#        </li>
#        <li class="mobile-hide">
#         <a href="http://www.successories.com/iquote/my">
#          My Quotes
#         </a>
#        </li>
#        <li class="mobile-hide">
#         <a href="http://www.successories.com/iquote/quoteology">
#          Quoteology
#         </a>
#        </li>
#        <li class="mobile-hide">
#         <a href="http://www.successories.com/iquote/today">
#          Today's iQuote
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="quotedb_quotelist">
#       <h1>
#        <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1" style="float:left; margin-right:10px;">
#         Abraham Lincoln Quotes
#        </a>
#       </h1>
#       <iframe allowtransparency="true" frameborder="0" scrolling="no" src="http://www.facebook.com/plugins/like.php?href=http%3A%2F%2Fwww.successories.com%2Fiquote%2Fauthor%2F291%2Fabraham-lincoln-quotes%2F1&amp;send=false&amp;layout=button_count&amp;width=100&amp;show_faces=false&amp;action=like&amp;colorscheme=light&amp;font&amp;height=21" style="border:none; overflow:hidden; width:100px; height:21px; float:left;">
#       </iframe>
#       <br clear="all"/>
#       <h3>
#        <ul class="pager">
#         <li class="on">
#          <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">
#           1
#          </a>
#         </li>
#         <li>
#          <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/2">
#           2
#          </a>
#         </li>
#         <li>
#          <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/3">
#           3
#          </a>
#         </li>
#         <li>
#          <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/4">
#           4
#          </a>
#         </li>
#         <li>
#          <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/5">
#           5
#          </a>
#         </li>
#         <li class="ellipsis">
#          <span>
#           ...
#          </span>
#         </li>
#         <li>
#          <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/44">
#           44
#          </a>
#         </li>
#         <li>
#          <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/2">
#           <img alt="Next" height="8" src="images/gfx-listview/pager-next.gif" width="8"/>
#          </a>
#         </li>
#        </ul>
#        440 quotes:
#       </h3>
#       <div class="quotebox">
#        <div class="quote">
#         <a onclick="location = 'http://www.successories.com/iquote/quote/989347/i-am-for-those-means-which-will-give-the-greatest-good-to-the-greatest-number'; return false;">
#          "I am for those means which will give the greatest good to the greatest number."
#         </a>
#        </div>
#        <div class="aboutquote">
#         <span class="author">
#          Author:
#          <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">
#           Lincoln Quotes
#          </a>
#         </span>
#         Category:
#         <i>
#          None
#         </i>
#        </div>
#        <div class="quote_actions">
#         <div class="wingdings" id="quote_controls_989347">
#         </div>
#         <script type="text/javascript">
#          new Quote(989347,"",false);
#         </script>
#        </div>
#       </div>
#       <!-- Go to www.addthis.com/dashboard to customize your tools -->
#       <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript">
#       </script>
#       <div class="quotebox">
#        <div class="quote">
#         <a onclick="location = 'http://www.successories.com/iquote/quote/111287/having-thus-chosen-our-course-without-guile-and-with-pure-purpose-let-us-renew-our-trust-in-god-a'; return false;">
#          "Having thus chosen our course, without guile and with pure purpose, let us renew our trust in God, and go forward without fear and with manly hearts."
#         </a>
#        </div>
#        <div class="aboutquote">
#         <span class="author">
#          Author:
#          <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">
#           Lincoln Quotes
#          </a>
#         </span>
#         Category:
#         <a href="http://www.successories.com/iquote/category/392/brave-quotes/1">
#          Brave Quotes
#         </a>
#         Respectability Quotes
#        </div>
#        <div class="quote_actions">
#         <div class="wingdings" id="quote_controls_111287">
#         </div>
#         <script type="text/javascript">
#          new Quote(111287,"",false);
#         </script>
#        </div>
#       </div>
#       <!-- Go to www.addthis.com/dashboard to customize your tools -->
#       <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript">
#       </script>
#       <div class="quotebox">
#        <div class="quote">
#         <a onclick="location = 'http://www.successories.com/iquote/quote/73400/you-have-to-do-your-own-growing-no-matter-how-tall-your-grandfather-was'; return false;">
#          "You have to do your own growing no matter how tall your grandfather was."
#         </a>
#        </div>
# ...
#         </script>
#        </div>
#       </div>
#       <!-- Go to www.addthis.com/dashboard to customize your tools -->
#       <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript">
#       </script>
#       <div class="quotebox">
#        <div class="quote">
#         <a onclick="location = 'http://www.successories.com/iquote/quote/989371/lonely-men-seek-companionship-lonely-women-sit-at-home-and-wait-they-never-meet'; return false;">
#          "Lonely men seek companionship. Lonely women sit at home and wait. They never meet."
#         </a>
#        </div>
#        <div class="aboutquote">
#         <span class="author">
#          Author:
#          <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">
#           Lincoln Quotes
#          </a>
#         </span>
#         Category:
#         <i>
#          None
#         </i>
#        </div>
#        <div class="quote_actions">
#         <div class="wingdings" id="quote_controls_989371">
#         </div>
#         <script type="text/javascript">
#          new Quote(989371,"",false);
#         </script>
#        </div>
#       </div>
#       <!-- Go to www.addthis.com/dashboard to customize your tools -->
#       <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript">
#       </script>
#       <div class="quotebox">
#        <div class="quote">
#         <a onclick="location = 'http://www.successories.com/iquote/quote/989370/and-in-the-end-its-not-the-years-in-your-life-that-count-its-the-life-in-your-years'; return false;">
#          "And in the end it's not the years in your life that count. It's the life in your years."
#         </a>
#        </div>
#        <div class="aboutquote">
#         <span class="author">
#          Author:
#          <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">
#           Lincoln Quotes
#          </a>
#         </span>
#         Category:
#         <i>
#          None
#         </i>
#        </div>
#        <div class="quote_actions">
#         <div class="wingdings" id="quote_controls_989370">
#         </div>
#         <script type="text/javascript">
#          new Quote(989370,"",false);
#         </script>
#        </div>
#       </div>
#       <!-- Go to www.addthis.com/dashboard to customize your tools -->
#       <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript">
#       </script>
#       <div class="quotebox">
#        <div class="quote">
#         <a onclick="location = 'http://www.successories.com/iquote/quote/989369/it-is-difficult-to-make-a-man-miserable-while-he-feels-he-is-worthy-of-himself-and-claims-kindred-to'; return false;">
#          "It is difficult to make a man miserable while he feels he is worthy of himself and claims kindred to the great God who made him."
#         </a>
#        </div>
#        <div class="aboutquote">
#         <span class="author">
#          Author:
#          <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">
#           Lincoln Quotes
#          </a>
#         </span>
#         Category:
#         <i>
#          None
#         </i>
#        </div>
#        <div class="quote_actions">
#         <div class="wingdings" id="quote_controls_989369">
#         </div>
#         <script type="text/javascript">
#          new Quote(989369,"",false);
#         </script>
#        </div>
#       </div>
#       <!-- Go to www.addthis.com/dashboard to customize your tools -->
#       <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript">
#       </script>
#       <div class="quotebox">
#        <div class="quote">
#         <a onclick="location = 'http://www.successories.com/iquote/quote/989368/every-man-is-said-to-have-his-peculiar-ambition'; return false;">
#          "Every man is said to have his peculiar ambition."
#         </a>
#        </div>
#        <div class="aboutquote">
#         <span class="author">
#          Author:
#          <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">
#           Lincoln Quotes
#          </a>
#         </span>
#         Category:
#         <i>
#          None
#         </i>
#        </div>
#        <div class="quote_actions">
#         <div class="wingdings" id="quote_controls_989368">
#         </div>
#         <script type="text/javascript">
#          new Quote(989368,"",false);
#         </script>
#        </div>
#       </div>
#       <!-- Go to www.addthis.com/dashboard to customize your tools -->
#       <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript">
#       </script>
#       <ul class="pager">
#        <li class="on">
#         <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">
#          1
#         </a>
#        </li>
#        <li>
#         <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/2">
#          2
#         </a>
#        </li>
#        <li>
#         <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/3">
#          3
#         </a>
#        </li>
#        <li>
#         <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/4">
#          4
#         </a>
#        </li>
#        <li>
#         <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/5">
#          5
#         </a>
#        </li>
#        <li class="ellipsis">
#         <span>
#          ...
#         </span>
#        </li>
#        <li>
#         <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/44">
#          44
#         </a>
#        </li>
#        <li>
#         <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/2">
#          <img alt="Next" height="8" src="images/gfx-listview/pager-next.gif" width="8"/>
#         </a>
#        </li>
#       </ul>
#       <br clear="all"/>
#      </div>
#     </div>
#     <div id="quotedb-left-sidebar">
#      <a href="http://www.successories.com/iquote/authors/most">
#       <img alt="inspirational quote database" src="images/gfx-quotedb/quote-database2.gif" title="iQuote: Inspirational Quote Database"/>
#      </a>
#      <br/>
#      <br/>
#      <p>
#       Successories, the leaders of inspiration and motivation, has unlocked iQuote: The Inspirational Quote Database, a curated collection of the most inspirational quotes. Raise your iQ and become a Quoteologist today!
#      </p>
#      <br/>
#      <form action="http://www.successories.com/iquote/today/submit" method="post">
#       <div class="quote_signup2">
#        iQuote in your inbox!
#        <b>
#         Sign Up!
#        </b>
#        <br/>
#        <input class="typed" id="quote_email" name="email" type="text" value="enter your email address"/>
#        <script type="text/javascript">
#         setupFocusBlur("quote_email","enter your email address");
#        </script>
#        <input class="quote_signup-button" type="submit" value=""/>
#       </div>
#      </form>
#     </div>
#     <!-- END Content -->
#    </div>
#    <div class="push">
#    </div>
#   </div>
#   <!-- END Wrapper -->
#   <!-- START Footer -->
#   <div id="Clients">
#    <div class="ClientListTitle">
#     Successories has been providing motivation to organizations like yours since 1985
#    </div>
#    <div class="ClientList">
#    </div>
#   </div>
#   <div id="Footer-Signup">
#    <div id="container-secondary">
#     <div class="footer_email">
#      <div class="footer-title">
#       Sign up and Receive 10% Off:
#      </div>
#      <form action="https://www.successories.com/newsletter-signup" method="post">
#       <input class="signup_box" name="newsletter_email" onblur="leaveField(this, 'enter your email address');" onfocus="enterField(this, 'enter your email address');" style="color:#999999;" type="email" value="enter your email address"/>
#       <input class="btn_green btn_small" type="submit" value="Sign Up"/>
#      </form>
#     </div>
#     <div class="footer_social mobile-hide">
#      <div class="addthis_horizontal_follow_toolbox">
#      </div>
#      <div class="footer-title">
#       Stay Connected:
#      </div>
#     </div>
#     <div class="clear">
#     </div>
#    </div>
#   </div>
#   <div class="footer" id="footer">
#    <div class="footer-winter">
#    </div>
#    <div class="footer-content">
#     <div class="footer-onefourth firstfourth">
#      <div class="footerTitle">
#       Get Your FREE Successories Catalog
#      </div>
#      <a href="http://www.successories.com/catalog-request">
#       <img alt="Catalog" height="100px" src="images/gfx-home_page/2016-03-11/Catalog.png" width="111px"/>
#      </a>
#      <br clear="all"/>
#      <a href="http://www.successories.com/catalog-request">
#       Request a Catalog →
#      </a>
#      <br clear="all"/>
#     </div>
#     <div class="footer-onefourth secondfourth mobile-hide" onclick="window.open('http://www.successories.com/blog/?p=3264'); return false;">
#      <img border="0" height="59" src="images/gfx-footer/UPS-white.png" width="50"/>
#      <div>
#       We Proudly Ship
#       <br/>
#       Using UPS
#       <br/>
#       carbon neutral
#      </div>
#     </div>
#     <div class="footer-onefourth thirdfourth">
#      <div class="cc-badges" onclick="window.open('https://sealinfo.thawte.com/thawtesplash?form_file=fdf/thawtesplash.fdf&amp;dn=WWW.SUCCESSORIES.COM&amp;lang=en'); return false;">
#       Secure Checkout by Thawte. Powered by Paypal.
#      </div>
#      <div class="bestplacestowork mobile-hide" onclick="window.open('http://www.successories.com/blog/2015/09/30/successories-named-best-place-to-work/'); return false;">
#       Voted Best Places to Work Year after Year
#      </div>
#     </div>
#     <div class="footer-onefourth fourthfourth">
#      <div class="footerTitle">
#       Customer Service:
#      </div>
#      <li>
#       <a onclick="location='http://www.successories.com/contact-us'">
#        Contact Us
#       </a>
#      </li>
#      <li>
#       <a onclick="location='http://www.successories.com/guarantee'">
#        100% Satisfaction Guarantee
#       </a>
#      </li>
#      <li>
#       <a onclick="location='http://www.successories.com/art-requirements'">
#        Art &amp; Logo Requirements
#       </a>
#      </li>
#      <li>
#       <a onclick="location='http://www.successories.com/ordering-shipping'">
#        Ordering &amp; Shipping
#       </a>
#      </li>
#      <li>
#       <a onclick="location='http://www.successories.com/international-checkout'">
#        International Ordering
#       </a>
#      </li>
#      <li>
#       <a onclick="location='http://www.successories.com/returns-exchanges'">
#        Returns &amp; Exchanges
#       </a>
#      </li>
#      <li>
#       <a onclick="location='http://www.successories.com/categories/Closeout-and-Sale-Center/283/1'">
#        Outlet Center
#       </a>
#      </li>
#      <li>
#       <a onclick="location='http://www.successories.com/catalog-request'">
#        Request a Catalog
#       </a>
#      </li>
#      <br clear="all"/>
#      <div class="footerTitle">
#       Resources:
#      </div>
#      <li>
#       <a href="http://www.successories.com/Resources">
#        Whitepapers &amp; More
#       </a>
#      </li>
#      <li>
#       <a href="http://www.successories.com/blog">
#        Successories Blog
#       </a>
#      </li>
#      <li>
#       <a href="http://www.successories.com/iquote/authors">
#        Quote Database
#       </a>
#      </li>
#     </div>
#     <br clear="all"/>
#     <div class="clear">
#     </div>
#     <div class="subfooter">
#      <div class="copyrightLine clear">
#       800-535-2773 © Copyright 2016, Successories.com, LLC. All Rights Reserved.
#       <a onclick="location='http://www.successories.com/privacy'">
#        Privacy
#       </a>
#       |
#       <a onclick="location='http://www.successories.com/terms'">
#        Terms
#       </a>
#       |
#       <a href="http://www.successories.com/sitemap">
#        Site Map
#       </a>
#       <br clear="all"/>
#       <br clear="all"/>
#       <p>
#        <strong>
#         Terms &amp; Conditions:
#        </strong>
#        Must use desired promo code in cart. Minimum merchandise purchase may apply. Can expire or change at anytime. Limited 1 time use per customer. Limited to US &amp; Canadian orders. Shipping offers limited to Contiguous US shipping addresses with ground service to one location. Cannot be combined with any other discounts or promotions such as sale items, quantity discounts, and multiple promo codes. Promotion excludes promotional products. Other exclusions may apply. Promotion does not apply to previous purchases, taxes, or other shipping methods. Subject to adjustment due to returns, cancellations and exchanges. Valid only at www.successories.com
#       </p>
#      </div>
#      <br clear="all"/>
#     </div>
#     <!-- START RPC Header Update -->
#     <script type="text/javascript">
#      var s192="k4+E2VN30d4fmXK6XAqKrlP257WYOLEar8oT7Ujqey529IlpLEZKs+CXc/VydSQEbIY8raoFcpV3zGFUG2apPinVnq2f4rKCzZCZCVIkKDqeayrBB74JNRXyyoF2e2DdyJELymuSQR8rLkBngUQ/A7V2Twuz1Hp8XrqdaJnDEq0=";function s833(){var s91={v:s192};new Activa.rpc("http://www.successories.com/rpc/tr/p",{input:s91,onComplete:function(){}});s192="";}
# setInterval(s833,60000);Activa.DOM.ready(updateHeaderInfo);Activa.DOM.ready(s833);
#     </script>
#     <!-- Google Code for Remarketing Tag -->
#     <script type="text/javascript">
#      var google_tag_params = {"ecomm_pagetype":"other"};
#     </script>
#     <script type="text/javascript">
#      /* <![CDATA[ */
# var google_conversion_id = 1069719471;
# var google_custom_params = window.google_tag_params;
# var google_remarketing_only = true;
# /* ]]> */
#     </script>
#     <script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript">
#     </script>
#     <noscript>
#      <div style="display:inline;">
#       <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/1069719471/?value=0&amp;guid=ON&amp;script=0" style="border-style:none;" width="1"/>
#      </div>
#     </noscript>
#     <!-- BEGIN: Google Trusted Stores -->
#     <script type="text/javascript">
#      var gts = gts || [];
# gts.push(["id", "199541"]);
# gts.push(["locale", "en_US"]);
# gts.push(["google_base_subaccount_id", "199541"]);
# gts.push(["google_base_country", "US"]);
# gts.push(["google_base_language", "en"]);
# (function() {
# var scheme = (("https:" == document.location.protocol) ? "https://" : "http://");
# var gts = document.createElement("script");
# gts.type = "text/javascript";
# gts.async = true;
# gts.src = scheme + "www.googlecommerce.com/trustedstores/gtmp_compiled.js";
# var s = document.getElementsByTagName("script")[0];
# s.parentNode.insertBefore(gts, s);
# })();
#     </script>
#     <!-- END: Google Trusted Stores -->
#     <!-- START Bronto -->
#     <script type="text/javascript">
#      var _bsw = _bsw || [];
#   _bsw.push(['_bswId', '846aeb2eec3570f51a785acf3f0055cb4eca692c5b6785c2bf2e9aced32f9587']);
#   (function() {
#     var bsw = document.createElement('script'); bsw.type = 'text/javascript'; bsw.async = true;
#     bsw.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'js.bronto.com/s/b.min.js';
#     var t = document.getElementsByTagName('script')[0]; t.parentNode.insertBefore(bsw, t);
#   })();
#     </script>
#     <!-- END Bronto -->
#     <!-- START AddThis -->
#     <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript">
#     </script>
#     <!-- END AddThis -->
#    </div>
#    <!-- END Footer Container -->
#   </div>
#   <!-- END Footer -->
#  </body>
# </html>
# //anaconda/envs/py27/lib/python2.7/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 174 of the file //anaconda/envs/py27/lib/python2.7/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
print (b.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    Abraham Lincoln Quotes |  Successories | Quote Database | Motivational Posters
#   </title>
#   <meta content="The largest collection of Abraham Lincoln quotes. Successories iQuote Quote database has gathered 440 of Abraham Lincoln quotes. Search Abraham Lincoln quotes. Put quotes on Motivational Posters and Awards Recognition." name="description"/>
#   <meta content="en-us" http-equiv="Content-Language"/>
#   <meta content="Employee Gifts, Awards Recognition, Motivational Posters" name="classification"/>
#   <meta content="index,follow" name="robots"/>
#   <meta content="uJjzLV_M66fPgenvGXEETRewzeCLlM8tyfIn7UYw9zQ" name="google-site-verification"/>
#   <meta content="B015DAC7E38DC29941EBB997DC79B420" name="msvalidate.01"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width; initial-scale=1.0; maximum-scale=1.0; user-scalable=0;" name="viewport"/>
#   <base href="http://www.successories.com/"/>
#   <link href="http://www.successories.com/css/combined.php?1481728802" rel="stylesheet" type="text/css"/>
#   <!--[if IE 8]><link href="http://www.successories.com/css/ie8.css?1477683325" rel="stylesheet" type="text/css" /><![endif]-->
#   <link href="http://www.successories.com/images/favicon.ico?1477683325" rel="shortcut icon"/>
#   <link href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1" rel="canonical"/>
#   <script src="http://www.successories.com/framework/js/combined.php?1481640934" type="text/javascript">
#   </script>
#  </head>
#  <body style="margin:0; padding:0; color:#333;	background-color:#FCFCFC;">
#   <script type="text/javascript">
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){(i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)})(window,document,'script','//www.google-analytics.com/analytics.js','ga');ga('create','UA-1071924-1','successories.com');ga('require','displayfeatures');ga('send','pageview');
#   </script>
#   <div class="wrapper" style="min-height: 100%; height: auto; height: 100%;">
#    <script type="text/javascript">
#     var main_menu=new MainMenu("header_submenus");main_menu.addMenuItem(new MainMenuItem("menu_motivational_posters","submenu_motivational_posters","motivational_posters",250));main_menu.addMenuItem(new MainMenuItem("menu_awards_recognition","submenu_awards_recognition","awards_recognition",250));main_menu.addMenuItem(new MainMenuItem("menu_gifts","submenu_gifts","gifts",250));main_menu.addMenuItem(new MainMenuItem("menu_meetings","submenu_meetings","meetings",250));main_menu.addMenuItem(new MainMenuItem("menu_cards","submenu_cards","cards",250));main_menu.addMenuItem(new MainMenuItem("menu_books","submenu_books","books",250));main_menu.addMenuItem(new MainMenuItem("menu_create","submenu_create","create",250));main_menu.addMenuItem(new MainMenuItem("menu_themes","submenu_themes","themes",250));
#    </script>
#    <div id="offer_sw">
#     <div class="offer_sw" id="header-source-banner" style="display: none">
#     </div>
#     <div class="offer_sw" id="header-sitewide-banner">
#     </div>
#    </div>
#    <div class="header-snow">
#    </div>
#    <div id="header" style="margin: 0; padding: 0 0 1px; position: relative;">
#     <div id="header-container-outter">
#      <div id="header-container" style="position: relative; width: 980px; margin: 0 auto; 	height:80px;">
#       <div id="logo" style="left: 15px; position: absolute; top: 0;">
#        <a href="http://www.successories.com/">
#         <img alt="Successories Employee Motivational Gifts and Awards" class="headercart" src="images/gfx-header/Successories-Employee-Motivational-Gifts-and-Awards.png"/>
#        </a>
#       </div>
#       <a class="header-icon" href="http://www.successories.com/cart" id="header_cart_snapshot">
#        <img src="images/gfx-header/cart2.png"/>
#        <span class="carttotal" id="header-cart-snapshot">
#         0 items
#        </span>
#       </a>
#       <a class="header-icon" href="https://www.successories.com/account/favorite-products" id="header_favorites_snapshot">
#        <img class="header-favorite" src="images/gfx-header/favorite.png"/>
#        <span>
#         Account
#        </span>
#       </a>
#       <div class="header-icon mobile-sm-hide" id="header_phone_number" style="display:none">
#        <strong>
#         1-800-535-2773
#        </strong>
#        <br/>
#        <span>
#         Call Us 8am-10pm ET
#        </span>
#       </div>
#       <a class="mobile-sm-show header-icon" href="tel:18005352773" id="header-global-call-mobile">
#        <img onclick="" src="images/gfx-header/call-mobile.jpg"/>
#       </a>
#       <a class="header-icon" id="header_menu_mobile-show" onclick="Activa.DOM.addClass('header-global-nav', 'show'); Activa.DOM.showID('header_menu_mobile-hide'); Activa.DOM.hideID('header_menu_mobile-show'); Activa.DOM.hideID('header-global-search-mobile');">
#        <img class="header-menu" src="images/gfx-header/menu-mobile.jpg"/>
#       </a>
#       <a class="header-icon" id="header_menu_mobile-hide" onclick="Activa.DOM.removeClass('header-global-nav', 'show'); Activa.DOM.showID('header_menu_mobile-show'); Activa.DOM.hideID('header_menu_mobile-hide'); Activa.DOM.hideID('header-global-search-mobile');" style="display:none">
#        <img class="header-menu" src="images/gfx-header/menu-mobile.jpg"/>
#       </a>
#       <a class="header-icon" id="header_search_mobile-show" onclick="Activa.DOM.showID('header-global-search-mobile'); Activa.DOM.showID('header_search_mobile-hide'); Activa.DOM.hideID('header_search_mobile-show'); Activa.DOM.removeClass('header-global-nav', 'show');">
#        <img class="header-search" src="images/gfx-header/search-mobile.jpg"/>
#       </a>
#       <a class="header-icon" id="header_search_mobile-hide" onclick="Activa.DOM.hideID('header-global-search-mobile'); Activa.DOM.showID('header_search_mobile-show'); Activa.DOM.hideID('header_search_mobile-hide'); Activa.DOM.removeClass('header-global-nav', 'show');" style="display:none">
#        <img src="images/gfx-header/search-mobile.jpg"/>
#       </a>
#       <div class="clear">
#       </div>
#      </div>
#      <div class="clear">
#      </div>
#     </div>
#     <div class="clear">
#     </div>
#    </div>
#    <div class="clear">
#    </div>
#    <div class="header-nav">
#     <div class="" id="header-global-nav">
#      <div class="header-global-nav-container">
#       <ul class="nav main clear">
#        <a href="http://www.successories.com/Office-Art-Posters/1" id="menu_motivational_posters">
#         Motivational
#         <br/>
#         Posters &amp; Art
#        </a>
#        <a href="http://www.successories.com/Employee-Awards-Recognition/1" id="menu_awards_recognition">
#         Awards &amp;
#         <br/>
#         Recognition
#        </a>
#        <a href="http://www.successories.com/Unique-Corporate-Gifts/1" id="menu_gifts">
#         Gifts &amp;
#         <br/>
#         Rewards
#        </a>
#        <a href="http://www.successories.com/Fun-Motivation-Gifts/1" id="menu_gifts">
#         Fun
#         <br/>
#         Motivation
#        </a>
#        <a href="http://www.successories.com/Motivational-Gifts/1" id="menu_meetings">
#         Meeting &amp; Event
#         <br/>
#         Giveaways
#        </a>
#        <a class="oneline" href="http://www.successories.com/Business-Greeting-Cards/1" id="menu_cards">
#         Cards
#        </a>
#        <a class="oneline" href="http://www.successories.com/Inspirational-Books/1" id="menu_books">
#         Books
#        </a>
#        <a href="http://www.successories.com/categories/Shop-By-Theme/5041/1" id="menu_themes">
#         Shop by
#         <br/>
#         Themes
#        </a>
#        <a href="http://www.successories.com/categories/Create-Your-Own/302/1" id="menu_create">
#         Custom
#         <br/>
#         Photo Gifts
#        </a>
#        <a class="oneline" href="http://www.successories.com/categories/New-Products/3499/1">
#         NEW
#        </a>
#        <a class="short red" href="http://www.successories.com/Employee-Holiday-Gifts/1?source=SW6DC3O">
#         Holiday
#         <br/>
#         Delivery
#        </a>
#        <a class="web-hide menu-close" onclick="Activa.DOM.removeClass('header-global-nav', 'show'); Activa.DOM.showID('header_menu_mobile-show'); Activa.DOM.hideID('header_menu_mobile-hide');">
#         [x] Close Menu
#        </a>
#       </ul>
#       <div class="clear">
#       </div>
#      </div>
#     </div>
#     <div id="header_submenus" style="display: none; overflow: hidden; height: 300px;">
#      <div id="submenu_motivational_posters" style="display: none;">
#       <div class="SubMenuBody">
#        <img class="loading-submenu" src="images/gfx-submenu/loading.gif"/>
#       </div>
#      </div>
#      <div id="submenu_awards_recognition" style="display: none;">
#       <div class="SubMenuBody">
#        <img alt="loading" class="loading-submenu" src="images/gfx-submenu/loading.gif"/>
#       </div>
#      </div>
#      <div id="submenu_gifts" style="display: none;">
#       <div class="SubMenuBody">
#        <img alt="loading" class="loading-submenu" src="images/gfx-submenu/loading.gif"/>
#       </div>
#      </div>
#      <div id="submenu_meetings" style="display: none;">
#       <div class="SubMenuBody">
#        <img alt="loading" class="loading-submenu" src="images/gfx-submenu/loading.gif"/>
#       </div>
#      </div>
#      <div id="submenu_cards" style="display: none;">
#       <div class="SubMenuBody">
#        <img alt="loading" class="loading-submenu" src="images/gfx-submenu/loading.gif"/>
#       </div>
#      </div>
#      <div id="submenu_books" style="display: none;">
#       <div class="SubMenuBody">
#        <img alt="loading" class="loading-submenu" src="images/gfx-submenu/loading.gif"/>
#       </div>
#      </div>
#      <div id="submenu_create" style="display: none;">
#       <div class="SubMenuBody">
#        <img alt="loading" class="loading-submenu" src="images/gfx-submenu/loading.gif"/>
#       </div>
#      </div>
#      <div id="submenu_themes" style="display: none;">
#       <div class="SubMenuBody">
#        <img alt="loading" class="loading-submenu" src="images/gfx-submenu/loading.gif"/>
#       </div>
#      </div>
#      <div id="submenu_events" style="display: none;">
#       <div class="SubMenuBody">
#        <img alt="loading" class="loading-submenu" src="images/gfx-submenu/loading.gif"/>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div id="header-global-search-mobile" style="display:none;">
#     <form action="http://www.successories.com/search/results" class="search" method="post" onsubmit="if ( this.elements['search'].value == 'enter your search' ) { alert('Please enter your search'); return false; } else { return true; } ">
#      <div class="searchInputs">
#       <input autocomplete="off" class="search_box" id="header_search" name="search" onblur="leaveField(this, 'What are you looking for?');" onfocus="enterField(this, 'What are you looking for?');" type="text" value="What are you looking for?"/>
#       <input class="btn_global_search" src="images/gfx-header/search.jpg" type="image" value="Search"/>
#      </div>
#     </form>
#    </div>
#    <a class="mobile-sm-show call-btn" href="tel:18005352773">
#     <img src="images/gfx-header/call.png"/>
#    </a>
#    <div class="clear" id="container">
#     <div class="clear" id="category">
#      <div class="clear" id="quotedb">
#       <ul class="quotedb_tabs clear">
#        <li>
#         <a href="http://www.successories.com/iquote/keywords">
#          Keywords
#         </a>
#        </li>
#        <li>
#         <a href="http://www.successories.com/iquote/categories">
#          Categories
#         </a>
#        </li>
#        <li class="current">
#         <a href="http://www.successories.com/iquote/authors">
#          Authors
#         </a>
#        </li>
#        <li class="mobile-hide">
#         <a href="http://www.successories.com/iquote/my">
#          My Quotes
#         </a>
#        </li>
#        <li class="mobile-hide">
#         <a href="http://www.successories.com/iquote/quoteology">
#          Quoteology
#         </a>
#        </li>
#        <li class="mobile-hide">
#         <a href="http://www.successories.com/iquote/today">
#          Today's iQuote
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="quotedb_quotelist">
#       <h1>
#        <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1" style="float:left; margin-right:10px;">
#         Abraham Lincoln Quotes
#        </a>
#       </h1>
#       <iframe allowtransparency="true" frameborder="0" scrolling="no" src="http://www.facebook.com/plugins/like.php?href=http%3A%2F%2Fwww.successories.com%2Fiquote%2Fauthor%2F291%2Fabraham-lincoln-quotes%2F1&amp;send=false&amp;layout=button_count&amp;width=100&amp;show_faces=false&amp;action=like&amp;colorscheme=light&amp;font&amp;height=21" style="border:none; overflow:hidden; width:100px; height:21px; float:left;">
#       </iframe>
#       <br clear="all"/>
#       <h3>
#        <ul class="pager">
#         <li class="on">
#          <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">
#           1
#          </a>
#         </li>
#         <li>
#          <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/2">
#           2
#          </a>
#         </li>
#         <li>
#          <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/3">
#           3
#          </a>
#         </li>
#         <li>
#          <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/4">
#           4
#          </a>
#         </li>
#         <li>
#          <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/5">
#           5
#          </a>
#         </li>
#         <li class="ellipsis">
#          <span>
#           ...
#          </span>
#         </li>
#         <li>
#          <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/44">
#           44
#          </a>
#         </li>
#         <li>
#          <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/2">
#           <img alt="Next" height="8" src="images/gfx-listview/pager-next.gif" width="8"/>
#          </a>
#         </li>
#        </ul>
#        440 quotes:
#       </h3>
#       <div class="quotebox">
#        <div class="quote">
#         <a onclick="location = 'http://www.successories.com/iquote/quote/989347/i-am-for-those-means-which-will-give-the-greatest-good-to-the-greatest-number'; return false;">
#          "I am for those means which will give the greatest good to the greatest number."
#         </a>
#        </div>
#        <div class="aboutquote">
#         <span class="author">
#          Author:
#          <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">
#           Lincoln Quotes
#          </a>
#         </span>
#         Category:
#         <i>
#          None
#         </i>
#        </div>
#        <div class="quote_actions">
#         <div class="wingdings" id="quote_controls_989347">
#         </div>
#         <script type="text/javascript">
#          new Quote(989347,"",false);
#         </script>
#        </div>
#       </div>
#       <!-- Go to www.addthis.com/dashboard to customize your tools -->
#       <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript">
#       </script>
#       <div class="quotebox">
#        <div class="quote">
#         <a onclick="location = 'http://www.successories.com/iquote/quote/111287/having-thus-chosen-our-course-without-guile-and-with-pure-purpose-let-us-renew-our-trust-in-god-a'; return false;">
#          "Having thus chosen our course, without guile and with pure purpose, let us renew our trust in God, and go forward without fear and with manly hearts."
#         </a>
#        </div>
#        <div class="aboutquote">
#         <span class="author">
#          Author:
#          <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">
#           Lincoln Quotes
#          </a>
#         </span>
#         Category:
#         <a href="http://www.successories.com/iquote/category/392/brave-quotes/1">
#          Brave Quotes
#         </a>
#         Respectability Quotes
#        </div>
#        <div class="quote_actions">
#         <div class="wingdings" id="quote_controls_111287">
#         </div>
#         <script type="text/javascript">
#          new Quote(111287,"",false);
#         </script>
#        </div>
#       </div>
#       <!-- Go to www.addthis.com/dashboard to customize your tools -->
#       <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript">
#       </script>
#       <div class="quotebox">
#        <div class="quote">
#         <a onclick="location = 'http://www.successories.com/iquote/quote/73400/you-have-to-do-your-own-growing-no-matter-how-tall-your-grandfather-was'; return false;">
#          "You have to do your own growing no matter how tall your grandfather was."
#         </a>
#        </div>
#        <div class="aboutquote">
#         <span class="author">
#          Author:
#          <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">
#           Lincoln Quotes
#          </a>
#         </span>
#         Category:
#         <a href="http://www.successories.com/iquote/category/160/american-president-quotes/1">
#          American President Quotes
#         </a>
#         <a href="http://www.successories.com/iquote/category/738/courage-quotes/1">
#          Courage Quotes
#         </a>
#        </div>
#        <div class="quote_actions">
#         <div class="wingdings" id="quote_controls_73400">
#         </div>
#         <script type="text/javascript">
#          new Quote(73400,"",false);
#         </script>
#        </div>
#       </div>
#       <!-- Go to www.addthis.com/dashboard to customize your tools -->
#       <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript">
#       </script>
#       <div class="quotebox">
#        <div class="quote">
#         <a onclick="location = 'http://www.successories.com/iquote/quote/73363/i-have-been-driven-many-times-to-my-knees-by-the-overwhelming-conviction-that-i-had-nowhere-to-go-m'; return false;">
#          "I have been driven many times to my knees by the overwhelming conviction that I had nowhere to go. My own wisdom, and that of all about me, seemed insufficient for the day."
#         </a>
#        </div>
#        <div class="aboutquote">
#         <span class="author">
#          Author:
#          <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">
#           Lincoln Quotes
#          </a>
#         </span>
#         Category:
#         <a href="http://www.successories.com/iquote/category/160/american-president-quotes/1">
#          American President Quotes
#         </a>
#         <a href="http://www.successories.com/iquote/category/719/conviction-quotes/1">
#          Conviction Quotes
#         </a>
#        </div>
#        <div class="quote_actions">
#         <div class="wingdings" id="quote_controls_73363">
#         </div>
#         <script type="text/javascript">
#          new Quote(73363,"",false);
#         </script>
#        </div>
#       </div>
#       <!-- Go to www.addthis.com/dashboard to customize your tools -->
#       <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript">
#       </script>
#       <div class="quotebox">
#        <div class="quote">
#         <a onclick="location = 'http://www.successories.com/iquote/quote/22247/i-see-a-very-dark-cloud-on-americas-horizon-and-that-cloud-is-coming-from-rome'; return false;">
#          "I see a very dark cloud on America's horizon, and that cloud is coming from Rome"
#         </a>
#        </div>
#        <div class="aboutquote">
#         <span class="author">
#          Author:
#          <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">
#           Lincoln Quotes
#          </a>
#         </span>
#         Category:
#         <a href="http://www.successories.com/iquote/category/116/america-quotes/1">
#          America Quotes
#         </a>
#        </div>
#        <div class="quote_actions">
#         <div class="wingdings" id="quote_controls_22247">
#         </div>
#         <script type="text/javascript">
#          new Quote(22247,"",false);
#         </script>
#        </div>
#       </div>
#       <!-- Go to www.addthis.com/dashboard to customize your tools -->
#       <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript">
#       </script>
#       <div class="quotebox">
#        <div class="quote">
#         <a onclick="location = 'http://www.successories.com/iquote/quote/10363/things-may-come-to-those-who-wait-but-only-the-things-left-by-those-who-hustle'; return false;">
#          "Things may come to those who wait...but only the things left by those who hustle."
#         </a>
#        </div>
#        <div class="aboutquote">
#         <span class="author">
#          Author:
#          <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">
#           Lincoln Quotes
#          </a>
#         </span>
#         Category:
#         <a href="http://www.successories.com/iquote/category/87/achievement-quotes/1">
#          Achievement Quotes
#         </a>
#        </div>
#        <div class="quote_actions">
#         <div class="wingdings" id="quote_controls_10363">
#         </div>
#         <script type="text/javascript">
#          new Quote(10363,"",false);
#         </script>
#        </div>
#       </div>
#       <!-- Go to www.addthis.com/dashboard to customize your tools -->
#       <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript">
#       </script>
#       <div class="quotebox">
#        <div class="quote">
#         <a onclick="location = 'http://www.successories.com/iquote/quote/989371/lonely-men-seek-companionship-lonely-women-sit-at-home-and-wait-they-never-meet'; return false;">
#          "Lonely men seek companionship. Lonely women sit at home and wait. They never meet."
#         </a>
#        </div>
#        <div class="aboutquote">
#         <span class="author">
#          Author:
#          <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">
#           Lincoln Quotes
#          </a>
#         </span>
#         Category:
#         <i>
#          None
#         </i>
#        </div>
#        <div class="quote_actions">
#         <div class="wingdings" id="quote_controls_989371">
#         </div>
#         <script type="text/javascript">
#          new Quote(989371,"",false);
#         </script>
#        </div>
#       </div>
#       <!-- Go to www.addthis.com/dashboard to customize your tools -->
#       <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript">
#       </script>
#       <div class="quotebox">
#        <div class="quote">
#         <a onclick="location = 'http://www.successories.com/iquote/quote/989370/and-in-the-end-its-not-the-years-in-your-life-that-count-its-the-life-in-your-years'; return false;">
#          "And in the end it's not the years in your life that count. It's the life in your years."
#         </a>
#        </div>
#        <div class="aboutquote">
#         <span class="author">
#          Author:
#          <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">
#           Lincoln Quotes
#          </a>
#         </span>
#         Category:
#         <i>
#          None
#         </i>
#        </div>
#        <div class="quote_actions">
#         <div class="wingdings" id="quote_controls_989370">
#         </div>
#         <script type="text/javascript">
#          new Quote(989370,"",false);
#         </script>
#        </div>
#       </div>
#       <!-- Go to www.addthis.com/dashboard to customize your tools -->
#       <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript">
#       </script>
#       <div class="quotebox">
#        <div class="quote">
#         <a onclick="location = 'http://www.successories.com/iquote/quote/989369/it-is-difficult-to-make-a-man-miserable-while-he-feels-he-is-worthy-of-himself-and-claims-kindred-to'; return false;">
#          "It is difficult to make a man miserable while he feels he is worthy of himself and claims kindred to the great God who made him."
#         </a>
#        </div>
#        <div class="aboutquote">
#         <span class="author">
#          Author:
#          <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">
#           Lincoln Quotes
#          </a>
#         </span>
#         Category:
#         <i>
#          None
#         </i>
#        </div>
#        <div class="quote_actions">
#         <div class="wingdings" id="quote_controls_989369">
#         </div>
#         <script type="text/javascript">
#          new Quote(989369,"",false);
#         </script>
#        </div>
#       </div>
#       <!-- Go to www.addthis.com/dashboard to customize your tools -->
#       <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript">
#       </script>
#       <div class="quotebox">
#        <div class="quote">
#         <a onclick="location = 'http://www.successories.com/iquote/quote/989368/every-man-is-said-to-have-his-peculiar-ambition'; return false;">
#          "Every man is said to have his peculiar ambition."
#         </a>
#        </div>
#        <div class="aboutquote">
#         <span class="author">
#          Author:
#          <a href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">
#           Lincoln Quotes
#          </a>
#         </span>
#         Category:
#         <i>
#          None
#         </i>
#        </div>
#        <div class="quote_actions">
#         <div class="wingdings" id="quote_controls_989368">
#         </div>
#         <script type="text/javascript">
#          new Quote(989368,"",false);
#         </script>
#        </div>
#       </div>
#       <!-- Go to www.addthis.com/dashboard to customize your tools -->
#       <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript">
#       </script>
#       <ul class="pager">
#        <li class="on">
#         <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/1">
#          1
#         </a>
#        </li>
#        <li>
#         <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/2">
#          2
#         </a>
#        </li>
#        <li>
#         <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/3">
#          3
#         </a>
#        </li>
#        <li>
#         <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/4">
#          4
#         </a>
#        </li>
#        <li>
#         <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/5">
#          5
#         </a>
#        </li>
#        <li class="ellipsis">
#         <span>
#          ...
#         </span>
#        </li>
#        <li>
#         <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/44">
#          44
#         </a>
#        </li>
#        <li>
#         <a class="pager-link" href="http://www.successories.com/iquote/author/291/abraham-lincoln-quotes/2">
#          <img alt="Next" height="8" src="images/gfx-listview/pager-next.gif" width="8"/>
#         </a>
#        </li>
#       </ul>
#       <br clear="all"/>
#      </div>
#     </div>
#     <div id="quotedb-left-sidebar">
#      <a href="http://www.successories.com/iquote/authors/most">
#       <img alt="inspirational quote database" src="images/gfx-quotedb/quote-database2.gif" title="iQuote: Inspirational Quote Database"/>
#      </a>
#      <br/>
#      <br/>
#      <p>
#       Successories, the leaders of inspiration and motivation, has unlocked iQuote: The Inspirational Quote Database, a curated collection of the most inspirational quotes. Raise your iQ and become a Quoteologist today!
#      </p>
#      <br/>
#      <form action="http://www.successories.com/iquote/today/submit" method="post">
#       <div class="quote_signup2">
#        iQuote in your inbox!
#        <b>
#         Sign Up!
#        </b>
#        <br/>
#        <input class="typed" id="quote_email" name="email" type="text" value="enter your email address"/>
#        <script type="text/javascript">
#         setupFocusBlur("quote_email","enter your email address");
#        </script>
#        <input class="quote_signup-button" type="submit" value=""/>
#       </div>
#      </form>
#     </div>
#     <!-- END Content -->
#    </div>
#    <div class="push">
#    </div>
#   </div>
#   <!-- END Wrapper -->
#   <!-- START Footer -->
#   <div id="Clients">
#    <div class="ClientListTitle">
#     Successories has been providing motivation to organizations like yours since 1985
#    </div>
#    <div class="ClientList">
#    </div>
#   </div>
#   <div id="Footer-Signup">
#    <div id="container-secondary">
#     <div class="footer_email">
#      <div class="footer-title">
#       Sign up and Receive 10% Off:
#      </div>
#      <form action="https://www.successories.com/newsletter-signup" method="post">
#       <input class="signup_box" name="newsletter_email" onblur="leaveField(this, 'enter your email address');" onfocus="enterField(this, 'enter your email address');" style="color:#999999;" type="email" value="enter your email address"/>
#       <input class="btn_green btn_small" type="submit" value="Sign Up"/>
#      </form>
#     </div>
#     <div class="footer_social mobile-hide">
#      <div class="addthis_horizontal_follow_toolbox">
#      </div>
#      <div class="footer-title">
#       Stay Connected:
#      </div>
#     </div>
#     <div class="clear">
#     </div>
#    </div>
#   </div>
#   <div class="footer" id="footer">
#    <div class="footer-winter">
#    </div>
#    <div class="footer-content">
#     <div class="footer-onefourth firstfourth">
#      <div class="footerTitle">
#       Get Your FREE Successories Catalog
#      </div>
#      <a href="http://www.successories.com/catalog-request">
#       <img alt="Catalog" height="100px" src="images/gfx-home_page/2016-03-11/Catalog.png" width="111px"/>
#      </a>
#      <br clear="all"/>
#      <a href="http://www.successories.com/catalog-request">
#       Request a Catalog →
#      </a>
#      <br clear="all"/>
#     </div>
#     <div class="footer-onefourth secondfourth mobile-hide" onclick="window.open('http://www.successories.com/blog/?p=3264'); return false;">
#      <img border="0" height="59" src="images/gfx-footer/UPS-white.png" width="50"/>
#      <div>
#       We Proudly Ship
#       <br/>
#       Using UPS
#       <br/>
#       carbon neutral
#      </div>
#     </div>
#     <div class="footer-onefourth thirdfourth">
#      <div class="cc-badges" onclick="window.open('https://sealinfo.thawte.com/thawtesplash?form_file=fdf/thawtesplash.fdf&amp;dn=WWW.SUCCESSORIES.COM&amp;lang=en'); return false;">
#       Secure Checkout by Thawte. Powered by Paypal.
#      </div>
#      <div class="bestplacestowork mobile-hide" onclick="window.open('http://www.successories.com/blog/2015/09/30/successories-named-best-place-to-work/'); return false;">
#       Voted Best Places to Work Year after Year
#      </div>
#     </div>
#     <div class="footer-onefourth fourthfourth">
#      <div class="footerTitle">
#       Customer Service:
#      </div>
#      <li>
#       <a onclick="location='http://www.successories.com/contact-us'">
#        Contact Us
#       </a>
#      </li>
#      <li>
#       <a onclick="location='http://www.successories.com/guarantee'">
#        100% Satisfaction Guarantee
#       </a>
#      </li>
#      <li>
#       <a onclick="location='http://www.successories.com/art-requirements'">
#        Art &amp; Logo Requirements
#       </a>
#      </li>
#      <li>
#       <a onclick="location='http://www.successories.com/ordering-shipping'">
#        Ordering &amp; Shipping
#       </a>
#      </li>
#      <li>
#       <a onclick="location='http://www.successories.com/international-checkout'">
#        International Ordering
#       </a>
#      </li>
#      <li>
#       <a onclick="location='http://www.successories.com/returns-exchanges'">
#        Returns &amp; Exchanges
#       </a>
#      </li>
#      <li>
#       <a onclick="location='http://www.successories.com/categories/Closeout-and-Sale-Center/283/1'">
#        Outlet Center
#       </a>
#      </li>
#      <li>
#       <a onclick="location='http://www.successories.com/catalog-request'">
#        Request a Catalog
#       </a>
#      </li>
#      <br clear="all"/>
#      <div class="footerTitle">
#       Resources:
#      </div>
#      <li>
#       <a href="http://www.successories.com/Resources">
#        Whitepapers &amp; More
#       </a>
#      </li>
#      <li>
#       <a href="http://www.successories.com/blog">
#        Successories Blog
#       </a>
#      </li>
#      <li>
#       <a href="http://www.successories.com/iquote/authors">
#        Quote Database
#       </a>
#      </li>
#     </div>
#     <br clear="all"/>
#     <div class="clear">
#     </div>
#     <div class="subfooter">
#      <div class="copyrightLine clear">
#       800-535-2773 © Copyright 2016, Successories.com, LLC. All Rights Reserved.
#       <a onclick="location='http://www.successories.com/privacy'">
#        Privacy
#       </a>
#       |
#       <a onclick="location='http://www.successories.com/terms'">
#        Terms
#       </a>
#       |
#       <a href="http://www.successories.com/sitemap">
#        Site Map
#       </a>
#       <br clear="all"/>
#       <br clear="all"/>
#       <p>
#        <strong>
#         Terms &amp; Conditions:
#        </strong>
#        Must use desired promo code in cart. Minimum merchandise purchase may apply. Can expire or change at anytime. Limited 1 time use per customer. Limited to US &amp; Canadian orders. Shipping offers limited to Contiguous US shipping addresses with ground service to one location. Cannot be combined with any other discounts or promotions such as sale items, quantity discounts, and multiple promo codes. Promotion excludes promotional products. Other exclusions may apply. Promotion does not apply to previous purchases, taxes, or other shipping methods. Subject to adjustment due to returns, cancellations and exchanges. Valid only at www.successories.com
#       </p>
#      </div>
#      <br clear="all"/>
#     </div>
#     <!-- START RPC Header Update -->
#     <script type="text/javascript">
#      var s192="k4+E2VN30d4fmXK6XAqKrlP257WYOLEar8oT7Ujqey529IlpLEZKs+CXc/VydSQEbIY8raoFcpV3zGFUG2apPinVnq2f4rKCzZCZCVIkKDqeayrBB74JNRXyyoF2e2DdyJELymuSQR8rLkBngUQ/A7V2Twuz1Hp8XrqdaJnDEq0=";function s833(){var s91={v:s192};new Activa.rpc("http://www.successories.com/rpc/tr/p",{input:s91,onComplete:function(){}});s192="";}
# setInterval(s833,60000);Activa.DOM.ready(updateHeaderInfo);Activa.DOM.ready(s833);
#     </script>
#     <!-- Google Code for Remarketing Tag -->
#     <script type="text/javascript">
#      var google_tag_params = {"ecomm_pagetype":"other"};
#     </script>
#     <script type="text/javascript">
#      /* <![CDATA[ */
# var google_conversion_id = 1069719471;
# var google_custom_params = window.google_tag_params;
# var google_remarketing_only = true;
# /* ]]> */
#     </script>
#     <script src="//www.googleadservices.com/pagead/conversion.js" type="text/javascript">
#     </script>
#     <noscript>
#      <div style="display:inline;">
#       <img alt="" height="1" src="//googleads.g.doubleclick.net/pagead/viewthroughconversion/1069719471/?value=0&amp;guid=ON&amp;script=0" style="border-style:none;" width="1"/>
#      </div>
#     </noscript>
#     <!-- BEGIN: Google Trusted Stores -->
#     <script type="text/javascript">
#      var gts = gts || [];
# gts.push(["id", "199541"]);
# gts.push(["locale", "en_US"]);
# gts.push(["google_base_subaccount_id", "199541"]);
# gts.push(["google_base_country", "US"]);
# gts.push(["google_base_language", "en"]);
# (function() {
# var scheme = (("https:" == document.location.protocol) ? "https://" : "http://");
# var gts = document.createElement("script");
# gts.type = "text/javascript";
# gts.async = true;
# gts.src = scheme + "www.googlecommerce.com/trustedstores/gtmp_compiled.js";
# var s = document.getElementsByTagName("script")[0];
# s.parentNode.insertBefore(gts, s);
# })();
#     </script>
#     <!-- END: Google Trusted Stores -->
#     <!-- START Bronto -->
#     <script type="text/javascript">
#      var _bsw = _bsw || [];
#   _bsw.push(['_bswId', '846aeb2eec3570f51a785acf3f0055cb4eca692c5b6785c2bf2e9aced32f9587']);
#   (function() {
#     var bsw = document.createElement('script'); bsw.type = 'text/javascript'; bsw.async = true;
#     bsw.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'js.bronto.com/s/b.min.js';
#     var t = document.getElementsByTagName('script')[0]; t.parentNode.insertBefore(bsw, t);
#   })();
#     </script>
#     <!-- END Bronto -->
#     <!-- START AddThis -->
#     <script async="" src="//s7.addthis.com/js/300/addthis_widget.js#pubid=ra-54182f382da00209" type="text/javascript">
#     </script>
#     <!-- END AddThis -->
#    </div>
#    <!-- END Footer Container -->
#   </div>
#   <!-- END Footer -->
#  </body>
# </html>

# %%
r = b.find_all(name='div', attrs={'class':'quote'})

# %%
y= []
for qoute in r:
    y.append(r.qoute)

# %%
print (r)
# Out:
# [<div class="quote"><a onclick="location = 'http://www.successories.com/iquote/quote/989347/i-am-for-those-means-which-will-give-the-greatest-good-to-the-greatest-number'; return false;">"I am for those means which will give the greatest good to the greatest number."</a></div>, <div class="quote"><a onclick="location = 'http://www.successories.com/iquote/quote/111287/having-thus-chosen-our-course-without-guile-and-with-pure-purpose-let-us-renew-our-trust-in-god-a'; return false;">"Having thus chosen our course, without guile and with pure purpose, let us renew our trust in God, and go forward without fear and with manly hearts."</a></div>, <div class="quote"><a onclick="location = 'http://www.successories.com/iquote/quote/73400/you-have-to-do-your-own-growing-no-matter-how-tall-your-grandfather-was'; return false;">"You have to do your own growing no matter how tall your grandfather was."</a></div>, <div class="quote"><a onclick="location = 'http://www.successories.com/iquote/quote/73363/i-have-been-driven-many-times-to-my-knees-by-the-overwhelming-conviction-that-i-had-nowhere-to-go-m'; return false;">"I have been driven many times to my knees by the overwhelming conviction that I had nowhere to go. My own wisdom, and that of all about me, seemed insufficient for the day."</a></div>, <div class="quote"><a onclick="location = 'http://www.successories.com/iquote/quote/22247/i-see-a-very-dark-cloud-on-americas-horizon-and-that-cloud-is-coming-from-rome'; return false;">"I see a very dark cloud on America's horizon, and that cloud is coming from Rome"</a></div>, <div class="quote"><a onclick="location = 'http://www.successories.com/iquote/quote/10363/things-may-come-to-those-who-wait-but-only-the-things-left-by-those-who-hustle'; return false;">"Things may come to those who wait...but only the things left by those who hustle."</a></div>, <div class="quote"><a onclick="location = 'http://www.successories.com/iquote/quote/989371/lonely-men-seek-companionship-lonely-women-sit-at-home-and-wait-they-never-meet'; return false;">"Lonely men seek companionship. Lonely women sit at home and wait. They never meet."</a></div>, <div class="quote"><a onclick="location = 'http://www.successories.com/iquote/quote/989370/and-in-the-end-its-not-the-years-in-your-life-that-count-its-the-life-in-your-years'; return false;">"And in the end it's not the years in your life that count. It's the life in your years."</a></div>, <div class="quote"><a onclick="location = 'http://www.successories.com/iquote/quote/989369/it-is-difficult-to-make-a-man-miserable-while-he-feels-he-is-worthy-of-himself-and-claims-kindred-to'; return false;">"It is difficult to make a man miserable while he feels he is worthy of himself and claims kindred to the great God who made him."</a></div>, <div class="quote"><a onclick="location = 'http://www.successories.com/iquote/quote/989368/every-man-is-said-to-have-his-peculiar-ambition'; return false;">"Every man is said to have his peculiar ambition."</a></div>]
