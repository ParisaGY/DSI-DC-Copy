# %% [markdown]
# # Python Coding Challenge
#
# We've come a long way since week 1 and our first introduction to Project Euler (Oiler, who knows how to say it).  We're bringing it back full circle with a few of those code challenges.
#
# _If you previously successfully completed one or more of these challenges avoid going back and copying your previous solution.  There is a chance that interviewers will provide you a challenge that you have seen before and so you must act accordingly..._
# **Either**
# - Inform that interviewer that you have seen this challenge before and provide a sudo-code breakdown of how you previously solved it.  (shows both your integrity and ability to solve the problem quickly)
# - Act like you've never had this challenge before.  Pretend to think for a few minutes and then bang out your answer rapidly, they will be impressed!(Seriously, this is a joke. Don't do this one.)

# %% [markdown]
# # Largest palindrome product
#
# A palindromic number reads the same both ways. The largest palindrome made from the product of two 2-digit numbers is 9009 = 91 × 99.
#
# Find the largest palindrome made from the product of two 3-digit numbers.

# %%
# Ike

number = []
for x in range (999,100,-1):
    for y in range (999,100,-1):
        number.append(x * y) #multiplying every number in 999-100 with 999-100
 
sor_string = []
sortedlist = sorted(number,reverse = True) #sort list from highest to lowest
for z in sortedlist:
    sor_string.append(str(z)) #making the list a str
    
for a in sor_string: 
    if a == a[::-1]: #comparing the string with a flipped version of the string
        print a #if same print value
        break #print top value which is the max
# Out:
# 906609

# %%
# Nathan

#Get the combinations of all possible three digit multipliers. And keep them if the result is divisible by 2.
l1 = range(100,1000)
l2 = range(100,1000)
#Store the multiplcation combo results in our target value of X.
results = [i*y for i in l1 for y in l2]

for i in results:  
#Turn the string into a list.
    test1 = [x for x in str(i)]
#Check that the length of the list is divisible by two. If it is, keep it, else don't keep it.
    y = len(test1)%2==0
    if y == True:
        #Cut up the string into two items.
        chara = test1[0]+test1[1]+test1[2]
        charb = test1[5]+test1[4]+test1[3]
        #Return the concatenated string if the values are equal to each other.
        if int(chara)==int(charb):
            print i
# Out:
# 106601
# 119911
# 117711
# 110011
# 105501
# 101101
# 111111
# 121121
# 131131
# 141141
# 108801
# 143341
# 102201
# 165561
# 155551
# 127721
# 133331
# 168861
# 174471
# 180081
# 142241
# 102201
# 137731
# 154451
# 171171
# 189981
# 204402
# 210012
# 188881
# 182281
# 108801
# 111111
# 138831
# 141141
# 168861
# 171171
# 198891
# 219912
# 222222
# 219912
# 128821
# 201102
# 214412
# 227722
# 171171
# 215512
# 105501
# 133331
# 161161
# 178871
# 221122
# 238832
# 210012
# 111111
# 222222
# 117711
# 213312
# 219912
# 234432
# 255552
# 239932
# 122221
# 244442
# 111111
# 141141
# 171171
# 222222
# 252252
# 220022
# 201102
# 270072
# 202202
# 212212
# 222222
# 232232
# 242242
# 252252
# 262262
# 272272
# 282282
# 198891
# 239932
# 234432
# 219912
# 252252
# 234432
# 161161
# 168861
# 123321
# 156651
# 189981
# 213312
# 246642
# 279972
# 225522
# 256652
# 212212
# 219912
# 232232
# 239932
# 252252
# 259952
# 272272
# 279972
# 292292
# 299992
# 231132
# 174471
# 286682
# 215512
# 149941
# ...

# %% [markdown]
# # Summation of primes
#
# The sum of the primes below 10 is 2 + 3 + 5 + 7 = 17.
#
# Find the sum of all the primes below two million.

# %%
#Ritika: Work in progress

# J " - Create a list where all values divisble by 2,3,5,7,11,13,17,19 have been removed initially."

# Parisa - "Create a list that updates of numbers that are found out to be Primes" 

# Sam - 'experiment with recursive functions'

thing = []
for i in range(2, 10000):
    if all(i % x != 0 for x in range(2, i)):
        thing.append(i)

sum(thing)
# Out:
# 5736396

# %% [markdown]
# # Multiples of 3 and 5
#
# If we list all the natural numbers below 10 that are multiples of 3 or 5, we get 3, 5, 6 and 9. The sum of these multiples is 23.
#
# Find the sum of all the multiples of 3 or 5 below 1000.

# %%
# Neil

total = 0
for i in range(1,1000):
    if i%3==0 or i%5==0:
        total = total+i
print total
# Out:
# 233168

# %%
# Ike

number = [] #creating list called number
for i in range(0,1000,3): #values from 0 to 999 counted by 3
    number.append(i) #append to numbers list

ix = range(0,1000,3)


for j in range(0,1000,5): #values from 0 to 999 counted by 3
    number.append(j) #append to numbers list
    
numbers = list(set(number)) #Only keeps unique values
sum(numbers) #sum the values
# Out:
# 233168

# %%
# Ike 2.0
sum(list(set(range(0,1000,5)+range(0,1000,3))))
# Out:
# 233168
